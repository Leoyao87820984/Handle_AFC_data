# %%
import pandas as pd

# %%
def get_counts(anything):
    counts ={}
    for a in anything:
        if a in counts:
            counts[a] = counts[a] + 1
        else:
            counts[a] = 1
    return counts

# %%
pd.options.display.max_rows = 50
pd.options.display.max_columns = 21

# %%
path_arret = "F:/Stage/data/AFC/DM arret.txt"

# %%
arrets = pd.read_csv(path_arret, header=0, delimiter="\t", encoding="latin-1")
arrets
# Out:
#       COD_TLB_RES  COD_TLB_TRNS COD_TLB_ARRT_STTN COD_STF_RES  COD_STF_TRNS  \
# 0             123           168     1133                  913            68
# 1             208           108     3244                  208           208
# 2             193           100     35808                 193           293
# 3             193           100     16161                 193           293
# 4             220           106     8320                  220             6
# 5             001             3     0030010068064         100           100
# 6             001             3     0030010763006         987           100
# 7             39            139     33                    39             39
# 8             55            155     604                   55             55
# 9             57            157     524                   57             57
# 10            45            145     45479                 45             45
# ...

# %%
len(get_counts(arrets['COD_STF_TRNS']))
# Out:
# 80

# %%
arrets = arrets[arrets.ZONS_ARRT != 'ND ']
arrets = arrets[arrets.COOR_X_PHSQ != '-1']
arrets['COD_TLB_ARRT_STTN'] = arrets['COD_TLB_ARRT_STTN'].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-3cd134dec68e> in <module>()
#       1 arrets = arrets[arrets.ZONS_ARRT != 'ND ']
#       2 arrets = arrets[arrets.COOR_X_PHSQ != '-1']
# ----> 3 arrets['COD_TLB_ARRT_STTN'] = arrets['COD_TLB_ARRT_STTN'].astype('int64')
#
# E:\python\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# E:\python\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    3408         # else, only a single dtype is given
#    3409         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# ...

# %%
arrets
# Out:
#       COD_TLB_RES  COD_TLB_TRNS COD_TLB_ARRT_STTN COD_STF_RES  COD_STF_TRNS  \
# 0             123           168     1133                  913            68
# 1             208           108     3244                  208           208
# 2             193           100     35808                 193           293
# 3             193           100     16161                 193           293
# 4             220           106     8320                  220             6
# 5             001             3     0030010068064         100           100
# 6             001             3     0030010763006         987           100
# 7             39            139     33                    39             39
# 9             57            157     524                   57             57
# 10            45            145     45479                 45             45
# 11            001             3     0030010166009         100           100
# ...

# %%
bus_202 = arrets[arrets['COD_TLB_ARRT_STTN'] == '0030030301200']

# %%
get_counts(arrets['COD_TLB_ARRT_STTN'])
# Out:
# {'1133         ': 13,
#  '3244         ': 2,
#  '35808        ': 1,
#  '16161        ': 1,
#  '8320         ': 2,
#  '0030010068064': 1,
#  '0030010763006': 1,
#  '33           ': 57,
#  '524          ': 21,
#  '45479        ': 1,
#  '0030010166009': 1,
#  '360          ': 34,
#  '1471         ': 10,
#  '50828        ': 1,
#  '253          ': 33,
#  '28242        ': 1,
#  '0030010098019': 1,
#  '0030010184027': 1,
#  '58801        ': 2,
#  '268          ': 25,
#  '1114         ': 15,
#  '50755        ': 1,
#  '0030010743038': 1,
#  '44           ': 56,
#  '1344         ': 13,
#  '0030010299028': 1,
#  '115          ': 47,
#  '36594        ': 1,
#  '36           ': 56,
#  '338          ': 39,
#  '347          ': 42,
#  '307          ': 32,
#  '556          ': 19,
#  '0030010116012': 1,
#  '329          ': 34,
#  '53571        ': 1,
#  '45117        ': 1,
#  '1436         ': 9,
#  '575          ': 22,
#  '558          ': 19,
#  '38           ': 54,
#  '279          ': 29,
# ...

# %%
bus_202
# Out:
#       COD_TLB_RES  COD_TLB_TRNS COD_TLB_ARRT_STTN COD_STF_RES  COD_STF_TRNS  \
# 46994         001             3     0030030301200         110           100
#
#       COD_STF_ARRT_STTN ZONS_ARRT  COD_ZON_PHSQ_MIN  \
# 46994               342       1                   1
#
#       DAT_DEBT_VALD_ZON_PHSQ_MIN  COD_INS_COMM  COD_ARRT_COMM  \
# 46994                 01/01/2006         75118            342
#
#        COD_ZON_PHSQ_MAX DAT_DEBT_VALD_ZON_PHSQ_MAX LIBL_COUR_ARRT_STTN  \
# 46994                 1                 01/01/2006      GUY MOQUET
#
#       LIBL_LONG_ARRT_STTN POL_PDU COOR_X_PHSQ COOR_Y_PHSQ CORR_DONN_STF  \
# 46994          GUY MOQUET       0  599333,101  132488,688             O
#
#        MOD_BUS  MOD_RER
# 46994        0        0

# %%
arrets[arrets['COD_TLB_RES'] == '005']
# Out:
# Empty DataFrame
# Columns: [COD_TLB_RES, COD_TLB_TRNS, COD_TLB_ARRT_STTN, COD_STF_RES, COD_STF_TRNS, COD_STF_ARRT_STTN, ZONS_ARRT, COD_ZON_PHSQ_MIN, DAT_DEBT_VALD_ZON_PHSQ_MIN, COD_INS_COMM, COD_ARRT_COMM, COD_ZON_PHSQ_MAX, DAT_DEBT_VALD_ZON_PHSQ_MAX, LIBL_COUR_ARRT_STTN, LIBL_LONG_ARRT_STTN, POL_PDU, COOR_X_PHSQ, COOR_Y_PHSQ, CORR_DONN_STF, MOD_BUS, MOD_RER]
# Index: []

# %%
bus_202 = bus_202[~bus_202.LIBL_LONG_ARRT_STTN.duplicated(keep='first')] #C'est genial

# %%
bus_202
# Out:
#    COD_TLB_RES  COD_TLB_TRNS COD_TLB_ARRT_STTN COD_STF_RES  COD_STF_TRNS  \
# 70         001             3     0030010714093         987           100
#
#    COD_STF_ARRT_STTN ZONS_ARRT  COD_ZON_PHSQ_MIN DAT_DEBT_VALD_ZON_PHSQ_MIN  \
# 70     0030010714093       3                   3                 01/01/2006
#
#     COD_INS_COMM  COD_ARRT_COMM  COD_ZON_PHSQ_MAX DAT_DEBT_VALD_ZON_PHSQ_MAX  \
# 70         92007          20145                 3                 01/01/2006
#
#    LIBL_COUR_ARRT_STTN LIBL_LONG_ARRT_STTN POL_PDU       COOR_X_PHSQ  \
# 70      MARCEL BONNET        MARCEL BONNET       0  598889,597335722
#
#          COOR_Y_PHSQ CORR_DONN_STF  MOD_BUS  MOD_RER
# 70  121694,320817214             O        1        0

# %%
arrets[arrets['COD_TLB_RES'] == '1  ']
# Out:
#       COD_TLB_RES  COD_TLB_TRNS COD_TLB_ARRT_STTN COD_STF_RES  COD_STF_TRNS  \
# 857           1             126     303                   501           501
# 2212          1             126     322                   501           501
# 6137          1             126     275                   501           501
# 7894          1             126     311                   501           501
# 9181          1             126     328                   501           501
# 9631          1             126     319                   501           501
# 17136         1             126     280                   501           501
# 18210         1             126     305                   501           501
# 19344         1             126     316                   501           501
# 20593         1             126     295                   501           501
# 29361         1             126     333                   501           501
# ...

# %%
path4 = "E:/Study/stif_gtfs/routes.txt"
routes = pd.read_csv(path4,header = 0)
routes
# Out:
#                 route_id  agency_id route_short_name  \
# 0          254177100:100        848              100
# 1      287191100:191-100        822          191-100
# 2     287094001:GOCparis        822        GO Cparis
# 3          057314100:100         95              100
# 4       057314143:ExpA14         95          Exp A14
# 5       057314142:ExpA14         95          Exp A14
# 6      116295008:FILEOFO        319         FILEO FO
# 7       116295003:FILEOG        319          FILEO G
# 8       116277005:FILEOO        319          FILEO O
# 9           116295032:32        319               32
# 10        116193100:100C        914             100C
# 11        116195100:100P        758             100P
# 12          116295027:27        319               27
# 13      116277010:FILEOV        319          FILEO V
# 14     116295004:FILEOVB        319         FILEO VB
# 15     116931007:FILEOVE        319         FILEO VE
# 16      116931002:FILEOT        319          FILEO T
# ...

# %%
get_counts(routes['route_type'])
# Out:
# {0: 10, 1: 16, 2: 14, 3: 1823, 7: 3}

# %%
path_agency = "E:/Study/stif_gtfs/agency.txt"
agency = pd.read_csv(path_agency, header = 0)
agency
# Out:
#      agency_id                                  agency_name  \
# 0          848                   Transdev Ile-de-France Lys
# 1          822                           Keolis Orly Rungis
# 2           95                                  Express A14
# 3          319                                        Filéo
# 4          914                                          KMR
# 5          758                                Busval d'Oise
# 6          584                                          TAM
# 7          750                              MAGICAL SHUTTLE
# 8          302                                      Com'Bus
# 9          303                                    Actipôles
# 10         285                                       Phébus
# 11         782                                        Titus
# 12         783                                Aubergenville
# 13         881                                 Paris-Saclay
# 14         658                                          ADP
# ...
