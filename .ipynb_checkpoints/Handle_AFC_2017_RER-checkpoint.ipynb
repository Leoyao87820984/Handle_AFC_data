# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.options.display.max_columns = 20 
pd.options.display.max_rows = 35
path_arret = "F:/Stage/data/AFC/DM arret.txt"
path_mode =  "F:/Stage/data/AFC/DM mode.txt"
path_nature = "F:/Stage/data/AFC/DM nature.txt"
path_transporteur = "F:/Stage/data/AFC/DM transporteur.txt"
path_RER = "F:/Stage/data/AFC/RER_A"

# %%
def get_counts(anything):
    counts = {}
    for  a in anything:
        if a in counts:
            counts[a] = counts[a] + 1
        else:
            counts[a] = 1
    return counts

# %%
RER = pd.read_csv(path_RER, delimiter="\t", header=0, encoding="latin-1")
# Out:
# E:\python\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
sort_RER = RER.sort_values('HEUR_VALD')

# %%
plot_data = 

#plt.savefig()

# %%
sns.distplot(sort_RER.HEUR_VALD, hist=False, rug=True)

# %%
times= get_counts(sort_RER.HEUR_VALD)

# %%
sort_RER.HEUR_VALD
# Out:
# 1212567    00:00:00
# 776735     00:00:00
# 162800     00:00:00
# 272924     00:00:00
# 695776     00:00:00
# 303458     00:00:01
# 831291     00:00:01
# 838871     00:00:02
# 954959     00:00:02
# 398430     00:00:02
# 505743     00:00:03
# 1310140    00:00:03
# 1411220    00:00:04
# 635237     00:00:05
# 754267     00:00:05
# 456710     00:00:05
# 363228     00:00:05
#              ...
# 678062     23:59:51
# 504261     23:59:51
# 58823      23:59:52
# 425499     23:59:52
# 53327      23:59:53
# 655797     23:59:53
# 736013     23:59:54
# 420542     23:59:54
# 155923     23:59:55
# 377143     23:59:56
# 32570      23:59:56
# 867575     23:59:57
# 802731     23:59:58
# 799556     23:59:58
# 745432     23:59:58
# 294561     23:59:59
# 1056229    23:59:59
# Name: HEUR_VALD, Length: 1798529, dtype: object

# %%
plt.plot(range(len(times)),times.values()) 
#plt.xticks(range(len(times)),times.keys(),rotation = 90)
plt.xlabel('Time')  
plt.ylabel('Count')
plt.legend()
plt.show()

# %%
arrets = get_counts(sort_RER.Lib_Arret)
plt.figure(figsize=(15,5))
plt.bar(arrets.keys(),arrets.values()) 
plt.xticks(rotation = 90)
plt.xlabel('arret')  
plt.ylabel('count')
plt.legend()
plt.show()

# %%
arret_full = pd.DataFrame([i for i in arrets.values()],index = arrets.keys(), columns=['counts'])
arret_full
# Out:
#                               counts
# AUBER                         159954
# CHATELET-LES HALLES           176582
# VAL-D'EUROPE                   17376
# CHAMPIGNY                      17318
# GARE DE LYON                  216592
# LE PARC-DE-SAINT-MAUR           9982
# CHARLES DE GAULLE ETOILE       95358
# NOISIEL                        17695
# BOISSY-SAINT-LEGER             12332
# LA DEFENSE-GRANDE ARCHE       238737
# NANTERRE-PREFECTURE            29068
# SUCY-BONNEUIL                  16546
# CHESSY - MARNE-LA-VALLEE       19215
# NATION                         98418
# NANTERRE-UNIVERSITE            28342
# VINCENNES                      45676
# VAL-DE-FONTENAY                58374
# ...                              ...
# HOUILLES-CARRIERES-SUR-SEINE   26322
# FONTENAY-SOUS-BOIS             16001
# NANTERRE-VILLE                 22952
# CHATOU-CROISSY                 14460
# LA VARENNE-CHENNEVIERES        13003
# NOGENT-SUR-MARNE               14109
# LE VESINET-CENTRE               6883
# BUSSY-SAINT-GEORGES            18526
# CERGY-SAINT-CHRISTOPHE         16385
# LE VESINET-LE PECQ             14970
# POISSY                         24567
# MAISONS-LAFFITTE                9324
# CERGY LE HAUT                  20895
# CERGY-PREFECTURE               34570
# NEUVILLE UNIVERSITE             3608
# ACHERES-VILLE                   4817
# ACHERES-GRAND-CORMIER             38
#
# [46 rows x 1 columns]

# %%
arret_dic = pd.read_csv(path_arret, delimiter="\t", header=0, encoding="latin-1")
arret_RER = (arret_dic[arret_dic['COD_STF_RES']=='801'])[['LIBL_LONG_ARRT_STTN','COOR_X_PHSQ','COOR_Y_PHSQ']]

# %%
arret_RER.index = arret_RER.LIBL_LONG_ARRT_STTN

# %%
arrtes_finall = arret_full.join(arret_RER)
arrtes_finall.drop_duplicates(keep="first", inplace = True)
arrtes_finall['COOR_X_PHSQ'] = arrtes_finall['COOR_X_PHSQ'].apply(lambda x: float((x.split(',')[0])))
arrtes_finall['COOR_Y_PHSQ'] = arrtes_finall['COOR_Y_PHSQ'].apply(lambda x: float((x.split(',')[0])))
arrtes_finall
# Out:
#                            counts        LIBL_LONG_ARRT_STTN  COOR_X_PHSQ  \
# ACHERES-GRAND-CORMIER          38      ACHERES-GRAND-CORMIER     582204.0
# ACHERES-VILLE                4817              ACHERES-VILLE     581054.0
# AUBER                      159954                      AUBER     599516.0
# BOISSY-SAINT-LEGER          12332         BOISSY-SAINT-LEGER     612355.0
# BRY-SUR-MARNE               12154              BRY-SUR-MARNE     613900.0
# BUSSY-SAINT-GEORGES         18526        BUSSY-SAINT-GEORGES     627340.0
# CERGY LE HAUT               20895              CERGY LE HAUT     576206.0
# CERGY-PREFECTURE            34570           CERGY-PREFECTURE     581211.0
# CERGY-SAINT-CHRISTOPHE      16385     CERGY-SAINT-CHRISTOPHE     577909.0
# CHAMPIGNY                   17318                  CHAMPIGNY     612764.0
# CHARLES DE GAULLE ETOILE    95358   CHARLES DE GAULLE ETOILE     596916.0
# CHATELET-LES HALLES        176582        CHATELET-LES HALLES     600769.0
# CHATOU-CROISSY              14460             CHATOU-CROISSY     586754.0
# CHESSY - MARNE-LA-VALLEE    19215   CHESSY - MARNE-LA-VALLEE     632695.0
# CONFLANS-FIN-D'OISE          9410        CONFLANS-FIN-D'OISE     580772.0
# FONTENAY-SOUS-BOIS          16001         FONTENAY-SOUS-BOIS     609334.0
# GARE DE LYON               216592               GARE DE LYON     602696.0
# ...                           ...                        ...          ...
# NATION                      98418                     NATION     604351.0
# NEUILLY-PLAISANCE           31195          NEUILLY-PLAISANCE     613010.0
# NEUVILLE UNIVERSITE          3608        NEUVILLE UNIVERSITE     581112.0
# NOGENT-SUR-MARNE            14109           NOGENT-SUR-MARNE     609921.0
# NOISIEL                     17695                    NOISIEL     620509.0
# NOISY-CHAMPS                25078               NOISY-CHAMPS     617876.0
# NOISY-LE-GRAND-MONT D'EST   37225  NOISY-LE-GRAND-MONT D'EST     615505.0
# POISSY                      24567                     POISSY     578354.0
# RUEIL-MALMAISON             33987            RUEIL-MALMAISON     587977.0
# SAINT-GERMAIN-EN-LAYE       29303      SAINT-GERMAIN-EN-LAYE     582280.0
# SAINT-MAUR-CRETEIL          23809         SAINT-MAUR-CRETEIL     610003.0
# SARTROUVILLE                23047               SARTROUVILLE     586854.0
# SUCY-BONNEUIL               16546              SUCY-BONNEUIL     612565.0
# TORCY                       19271                      TORCY     623386.0
# VAL-D'EUROPE                17376               VAL-D'EUROPE     632059.0
# VAL-DE-FONTENAY             58374            VAL-DE-FONTENAY     611129.0
# VINCENNES                   45676                  VINCENNES     607102.0
#
#                            COOR_Y_PHSQ
# ACHERES-GRAND-CORMIER         139475.0
# ACHERES-VILLE                 141176.0
# AUBER                         130190.0
# BOISSY-SAINT-LEGER            116862.0
# BRY-SUR-MARNE                 127176.0
# BUSSY-SAINT-GEORGES           126296.0
# CERGY LE HAUT                 149781.0
# CERGY-PREFECTURE              148493.0
# CERGY-SAINT-CHRISTOPHE        149971.0
# CHAMPIGNY                     122957.0
# CHARLES DE GAULLE ETOILE      130422.0
# CHATELET-LES HALLES           129040.0
# CHATOU-CROISSY                131657.0
# CHESSY - MARNE-LA-VALLEE      130041.0
# CONFLANS-FIN-D'OISE           143440.0
# FONTENAY-SOUS-BOIS            127035.0
# GARE DE LYON                  127075.0
# ...                                ...
# NATION                        127531.0
# NEUILLY-PLAISANCE             128128.0
# NEUVILLE UNIVERSITE           146010.0
# NOGENT-SUR-MARNE              125987.0
# NOISIEL                       127040.0
# NOISY-CHAMPS                  126963.0
# NOISY-LE-GRAND-MONT D'EST     126729.0
# POISSY                        137027.0
# RUEIL-MALMAISON               131917.0
# SAINT-GERMAIN-EN-LAYE         133100.0
# SAINT-MAUR-CRETEIL            122864.0
# SARTROUVILLE                  137498.0
# SUCY-BONNEUIL                 119034.0
# TORCY                         126623.0
# VAL-D'EUROPE                  128418.0
# VAL-DE-FONTENAY               128159.0
# VINCENNES                     127431.0
#
# [46 rows x 4 columns]

# %%
arrtes_finall.plot(kind="scatter", x="COOR_X_PHSQ", y = "COOR_Y_PHSQ", s = arrtes_finall["counts"]/1000)
plt.show()

# %%
get_counts(sort_RER.COD_NATR_VALD)
sort_RER['COD_NATR_VALD'] = sort_RER['COD_NATR_VALD'].astype('str')
sort_RER['HEUR_VALD'] = pd.to_datetime(sort_RER['HEUR_VALD'], format='%H:%M:%S')
get_counts(sort_RER.COD_NATR_VALD)
# Out:
# {'01 ': 25743,
#  '02 ': 18998,
#  '031': 10477,
#  '051': 103776,
#  '052': 100876,
#  '056': 27251,
#  '057': 25977,
#  '1': 69636,
#  '2': 58606,
#  '31': 31094,
#  '51': 475358,
#  '52': 450292,
#  '56': 189412,
#  '57': 210997,
#  'ND ': 36}

# %%
nature = pd.read_csv(path_nature, header=0 , delimiter="\t", encoding="latin-1")
nature
# Out:
#    COD_NATR_VALD COD_ENTR_SORT             LIBL_NATR_VALD  COD_MOD  \
# 0            3              3       Entree Correspondance        1
# 1            05A            1                  Entree RER        1
# 2            057            3   Sortie Correspondance RER        3
# 3            17             1                  Entree Bus        2
# 4            23             3   Sortie Correspondance RER        3
# 5            041            1              entree Tramway        4
# 6            05B            2                  Sortie RER        1
# 7            02             2                      Sortie        1
# 8            16             3          Correspondance Bus        2
# 9            01             1                      Entree       -1
# 10           04B            2              sortie Tramway        4
# 11           1              1                      Entree       -1
# 12           03A            1                entree Metro        3
# 13           2              2                      Sortie        1
# 14           042            2              sortie Tramway        4
# 15           011            1                  Entree Bus        2
# 16           11             1                  Entree Bus        2
# 17           04             3       Sortie Correspondance        3
# 18           016            3          Correspondance Bus        2
# 19           031            1                entree Metro        3
# 20           001            1                  Entree bus        2
# 21           056            3   Entree Correspondance RER        1
# 22           41             1                   entree T4        6
# 23           ND             ND                 NON DEFINI       -1
# 24           22             3   Entree Correspondance Bus        2
# 25           043            1         entree Tramway Sol.        4
# 26           052            2                  Sortie RER        1
# 27           5B             2                  Sortie RER        1
# 28           03             3       Entree Correspondance        1
# 29           051            1                  Entree RER        1
# 30           5A             1                  Entree RER        1
# 31           006            3          Correspondance Bus        2
# 32           04A            1              entree Tramway        4
# 33           4              3       Sortie Correspondance        3
# 34           010            1                  Entree Bus        2
#
#     COD_NATR_VALD_AGRG
# 0                    3
# 1                    2
# 2                    5
# 3                    1
# 4                    5
# 5                    7
# 6                    4
# 7                    4
# 8                    1
# 9                   10
# 10                   8
# 11                  10
# 12                   6
# 13                   4
# 14                   8
# 15                   1
# 16                   1
# 17                   5
# 18                   1
# 19                   6
# 20                   1
# 21                   3
# 22                   7
# 23                  -1
# 24                   1
# 25                   7
# 26                   4
# 27                   4
# 28                   3
# 29                   2
# 30                   2
# 31                   1
# 32                   7
# 33                   5
# 34                   1

# %%
entree = ['01 ', '031', '051', '056', '1', '31', '51', '56']
sortie = ['02 ', '052', '057', '2', '52', '57']

# %%
entree_nature = nature[nature['COD_NATR_VALD'].isin(entree)]
entree_nature
# Out:
#    COD_NATR_VALD COD_ENTR_SORT             LIBL_NATR_VALD  COD_MOD  \
# 9            01             1                      Entree       -1
# 19           031            1                entree Metro        3
# 21           056            3   Entree Correspondance RER        1
# 29           051            1                  Entree RER        1
#
#     COD_NATR_VALD_AGRG
# 9                   10
# 19                   6
# 21                   3
# 29                   2

# %%
sortie_nature = nature[nature['COD_NATR_VALD'].isin(sortie)]
sortie_nature
# Out:
#    COD_NATR_VALD COD_ENTR_SORT             LIBL_NATR_VALD  COD_MOD  \
# 2            057            3   Sortie Correspondance RER        3
# 7            02             2                      Sortie        1
# 26           052            2                  Sortie RER        1
#
#     COD_NATR_VALD_AGRG
# 2                    5
# 7                    4
# 26                   4

# %%
sort_RER = sort_RER.reset_index(drop=True)

# %%
sort_RER['HEUR_VALD'][100]
pd.Timestamp('19000101 15:23:23')
# Out:
# Timestamp('1900-01-01 15:23:23')

# %%
def select_time(start_time, end_time, data):
    year = '19000101 '
    start = pd.Timestamp(year+start_time)
    end = pd.Timestamp(year + end_time)
    new_data = data[(data['HEUR_VALD'] > start) & (data['HEUR_VALD'] < end) ]
    return new_data

# %%
sort_RER_entree =  sort_RER.query('COD_NATR_VALD == "057"|COD_NATR_VALD == "056"|COD_NATR_VALD == "01 "|COD_NATR_VALD == "031"|COD_NATR_VALD == "1"|COD_NATR_VALD == "31"|COD_NATR_VALD == "51"|COD_NATR_VALD == "56"')
len(sort_RER_entree)
# Out:
# 854948

# %%
sort_RER_sortie =  sort_RER.query('COD_NATR_VALD == "02 "|COD_NATR_VALD == "052"|COD_NATR_VALD == "057"|COD_NATR_VALD == "2"|COD_NATR_VALD == "52"|COD_NATR_VALD == "57"')
len(sort_RER_sortie)
# Out:
# 865746

# %%
index = get_counts(sort_RER_entree['Lib_Arret']).keys()
len(index)
# Out:
# 46

# %%
def OD_matrix(start_time, end_time, stop):
    new_data = select_time(start_time,end_time,sort_RER_entree)
    new_data = new_data[new_data['Lib_Arret'] == stop]
    print(len(new_data))
    final_data =select_time(start_time,end_time,sort_RER_sortie)
    final_data = final_data[final_data['NUMR_CART'].isin(new_data['NUMR_CART'])]
    print(len(final_data))
    counts = get_counts(final_data['Lib_Arret'])
    return pd.DataFrame([i for i in counts.values()], index = counts.keys(), columns = [stop])

# %%
OD = OD_matrix('11:30:00', '12:40:00', 'GARE DE LYON')
OD
# Out:
# 4110
# 2100
#                           GARE DE LYON
# GARE DE LYON                      1356
# NATION                              73
# CHATELET-LES HALLES                111
# NEUILLY-PLAISANCE                   15
# VINCENNES                           36
# VAL-DE-FONTENAY                     37
# AUBER                               71
# CHARLES DE GAULLE ETOILE            74
# NOGENT-SUR-MARNE                    10
# LA DEFENSE-GRANDE ARCHE            110
# NANTERRE-PREFECTURE                 14
# SAINT-MAUR-CRETEIL                  10
# LE PARC-DE-SAINT-MAUR                9
# NANTERRE-UNIVERSITE                 11
# CHAMPIGNY                           15
# LA VARENNE-CHENNEVIERES              5
# FONTENAY-SOUS-BOIS                   4
# ...                                ...
# NOISY-CHAMPS                        12
# SAINT-GERMAIN-EN-LAYE                3
# LE VESINET-LE PECQ                   2
# VAL-D'EUROPE                         7
# NOISIEL                              7
# LOGNES                               6
# NANTERRE-VILLE                       8
# TORCY                                7
# CERGY-PREFECTURE                     5
# POISSY                               1
# BUSSY-SAINT-GEORGES                  4
# LE VESINET-CENTRE                    1
# CHATOU-CROISSY                       1
# BOISSY-SAINT-LEGER                   2
# CHESSY - MARNE-LA-VALLEE             1
# CONFLANS-FIN-D'OISE                  2
# CERGY LE HAUT                        2
#
# [41 rows x 1 columns]

# %%
OD_7 = OD_matrix('07:00:00', '09:00:00', 'GARE DE LYON')
OD_9 = OD_matrix('09:00:00', '11:00:00', 'GARE DE LYON')
OD_11 = OD_matrix('11:00:00', '13:00:00', 'GARE DE LYON')
OD_13 = OD_matrix('13:00:00', '15:00:00', 'GARE DE LYON')
OD_15 = OD_matrix('15:00:00', '17:00:00', 'GARE DE LYON')
OD_17 = OD_matrix('17:00:00', '19:00:00', 'GARE DE LYON')
OD_19 = OD_matrix('19:00:00', '21:00:00', 'GARE DE LYON')
# Out:
# 20829
# 12850
# 9911
# 6726
# 6591
# 3686
# 7760
# 4226
# 13306
# 5894
# 29797
# 14084
# 15207
# 9414

# %%
OD_all = [OD_7, OD_9, OD_11, OD_13, OD_15, OD_17, OD_19]
labels = ['07:00:00 - 09:00:00', '09:00:00 - 11:00:00', '11:00:00 - 13:00:00', '13:00:00 - 15:00:00', 
'15:00:00 - 17:00:00', '17:00:00 - 19:00:00', '19:00:00 - 21:00:00']

# %%
for  i in range(len(OD_all)):
    RER_finall = OD_all[i].join(arret_RER)
    RER_finall.drop_duplicates(keep="first", inplace = True)
    RER_finall['COOR_X_PHSQ'] = RER_finall['COOR_X_PHSQ'].apply(lambda x: float((x.split(',')[0])))
    RER_finall['COOR_Y_PHSQ'] = RER_finall['COOR_Y_PHSQ'].apply(lambda x: float((x.split(',')[0])))
    RER_finall.plot(kind="scatter", x="COOR_X_PHSQ", y = "COOR_Y_PHSQ", s = RER_finall["GARE DE LYON"]/5, label = labels[i] )
plt.show()

# %%
try_path = 'F:/Stage/data/AFC/parts/part_21.txt'
try_test = pd.read_csv(try_path, header = 0, delimiter="\t", encoding="latin-1")
try_test
# Out:
# E:\python\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (6,9,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         Unnamed: 0             NUMR_CART JOUR_EXPL_VALD HEUR_VALD  \
# 0         10000000  89832956454731526754     14/03/2017  13:11:00
# 1         10000001  39846463822337477583     14/03/2017  20:41:16
# 2         10000002  20346703473675496051     14/03/2017  19:29:00
# 3         10000003  60728665230456429532     14/03/2017  13:04:20
# 4         10000004  60983309814606353688     14/03/2017  17:06:18
# 5         10000005  27957983567479680899     14/03/2017  13:29:48
# 6         10000006  82750756490689875739     14/03/2017  09:39:03
# 7         10000007  29676361871665297436     14/03/2017  14:53:22
# 8         10000008  90303180079144330252     14/03/2017  19:22:12
# 9         10000009  29749837935098674468     14/03/2017  20:36:52
# 10        10000010  63231580300538065396     14/03/2017  07:30:52
# 11        10000011  27467399583861562022     14/03/2017  20:01:44
# 12        10000012  86462506102460956718     14/03/2017  15:02:00
# 13        10000013  53434308931998365946     14/03/2017  17:39:39
# 14        10000014  68098880949907365777     14/03/2017  08:25:34
# 15        10000015  71134534577095099647     14/03/2017  14:17:00
# 16        10000016  67834399275550508476     14/03/2017  20:26:12
# ...            ...                   ...            ...       ...
# 499983    10499983  12382180090325837363     14/03/2017  18:14:19
# 499984    10499984  69921230383821091113     14/03/2017  08:05:00
# 499985    10499985  73454987419335704150     14/03/2017  21:51:12
# 499986    10499986  95413064504953046247     14/03/2017  09:58:00
# 499987    10499987  55522060054852383224     14/03/2017  08:20:10
# 499988    10499988  27656882298838906992     14/03/2017  17:14:18
# 499989    10499989  26937892835053574300     14/03/2017  15:13:00
# 499990    10499990  05132179754799115774     14/03/2017  10:32:07
# 499991    10499991  61923079673553834156     14/03/2017  16:22:56
# 499992    10499992  07135183551967758724     14/03/2017  17:10:25
# 499993    10499993  31300860601473544773     14/03/2017  07:28:13
# 499994    10499994  39365772532820743272     14/03/2017  10:26:26
# 499995    10499995  62130837922886597851     14/03/2017  14:23:36
# 499996    10499996  33515586020270952066     14/03/2017  07:47:15
# 499997    10499997  29657165088523214389     14/03/2017  08:39:00
# 499998    10499998  07815389595209503224     14/03/2017  06:51:27
# 499999    10499999  38354697020391668589     14/03/2017  09:05:00
#
#                                   Lib_Arret  COD_TLB_TRNS COD_TLB_RES  \
# 0                             Village Cargo           100         193
# 1                            SAINT-AUGUSTIN             3         001
# 2                                   PASTEUR             3         001
# 3                               SAINT-DENIS             2         002
# 4                                   LIBERTE             3         001
# 5                        TERNES - MAC MAHON             3         001
# 6                      MAISONS-ALFORT-STADE             3         001
# 7          BOBIGNY-PANTIN (RAYMOND QUENEAU)             3         001
# 8                                   Inconnu             3         001
# 9                           PORTE DE PANTIN             3         001
# 10                              JEAN JAURES             3         001
# 11                      NEUVILLE UNIVERSITE             1         801
# 12                             Henri Wallon           121         21
# 13                            GRIGNY-CENTRE             2         002
# 14                                VINCENNES             1         801
# 15                               LE NAOURES           145         45
# 16                  LA DEFENSE-GRANDE ARCHE             1         801
# ...                                     ...           ...         ...
# 499983                              MAGENTA             2           2
# 499984                              La Mare           113          13
# 499985                            RAMBUTEAU             3           1
# 499986                   LYCEE G . BRASSENS           102           2
# 499987              LA DEFENSE-GRANDE ARCHE             1         801
# 499988                  PORTE DE CHAMPERRET             3           1
# 499989                             Mazières           121          21
# 499990                     RICHELIEU-DROUOT             3           1
# 499991                 VERSAILLES-CHANTIERS             2           2
# 499992  CRETEIL-PREFECTURE (HOTEL DE VILLE)             3           1
# 499993                        CHOISY-LE-ROI             2           2
# 499994       HOTEL DE VILLE DE LA COURNEUVE             3           1
# 499995            LA PLAINE-STADE DE FRANCE             1         802
# 499996         HOUILLES-CARRIERES-SUR-SEINE             1         801
# 499997                         GARE DE LAGN           151          51
# 499998                         SAINT-LAZARE             3           1
# 499999                   Gare des Chantiers           156          56
#
#        COD_TLB_ARRT_STTN  NUMR_BORN_VALD_EQPM COD_NATR_VALD  COD_MOD_VALD  \
# 0          18632                        20652           11              2
# 1          0030030061000                  104           031             3
# 2          0030010128035                 1394           011             2
# 3          271015                     4500505           01              1
# 4          0030030251200                  102           031             3
# 5          0030010043049                10459           011             2
# 6          0030030251500                  103           031             3
# 7          0030030031100                  103           031             3
# 8          *112                         18461           041             4
# 9          0030030220100                  104           031             3
# 10         0030010068004                13573           011             2
# 11         334482                    13331101           01              1
# 12         1261                          4852           11              2
# 13         681379                     6451002           02              1
# 14         0030050160201                  410           052             1
# 15         45659                        20234           11              2
# 16         0030050170401                  109           031             3
# ...                  ...                  ...           ...           ...
# 499983     281873                    20500106           04              3
# 499984     770                          10189           11              2
# 499985     0030030080100                  104           031             3
# 499986     23                            4483           11              2
# 499987     0030050170401                  114           052             1
# 499988     0030030291200                  102           031             3
# 499989     1096                          4612           11              2
# 499990     0030030110700                  401           031             3
# 499991     393009                    19600701           02              1
# 499992     0030030250700                  103           031             3
# 499993     545285                    15410502           01              1
# 499994     0030010921034                 1011           041             4
# 499995     164798                    59510406           02              1
# 499996     386409                    48320704           01              1
# 499997     1903                         43058           11              2
# 499998     0030030060900                  203           031             3
# 499999     217                           1263           11              2
#
#         COD_STF_TRNS COD_STF_RES COD_STF_LIGN
# 0                293         193          100
# 1                100         110          ND
# 2                100         100          128
# 3                800         853          ND
# 4                100         110          ND
# 5                100         100          43
# 6                100         110          ND
# 7                100         110          ND
# 8                100         112          3
# 9                100         110          ND
# 10               100         100          68
# 11               810         801          ND
# 12                21         21           2
# 13               800         804          ND
# 14               810         801          ND
# 15                45         45           3
# 16               810         801          ND
# ...              ...         ...          ...
# 499983           800         805          ND
# 499984            13          13          10
# 499985           100         110          ND
# 499986             2           2          3
# 499987           810         801          ND
# 499988           100         110          ND
# 499989            21          21          11
# 499990           100         110          ND
# 499991           800         852          ND
# 499992           100         110          ND
# 499993           800         803          ND
# 499994           100         112          11
# 499995           810         802          ND
# 499996           810         801          ND
# 499997            51          51          42
# 499998           100         110          ND
# 499999            56         356          17
#
# [500000 rows x 14 columns]

# %%
x = try_test[try_test['Lib_Arret']=='GARE DE LYON']
flag = True
get_counts(x['COD_TLB_RES'])
# Out:
# {'001': 2722, 1: 258}

# %%
path_arret = "F:/Stage/data/AFC/DM arret.txt"
arret = pd.read_csv(path_arret, header = 0, delimiter="\t", encoding="latin-1")
arret[(arret['LIBL_LONG_ARRT_STTN'] == 'NATION') ]
# Out:
#       COD_TLB_RES  COD_TLB_TRNS COD_TLB_ARRT_STTN COD_STF_RES  COD_STF_TRNS  \
# 9177          001             3     0030010711056         987           100
# 19756         001             3     0030010057008         100           100
# 25898         001             3     0030030051000         110           100
# 31969         001             3     0030010733074         987           100
# 42049         001             3     0030010733005         987           100
# 72531         801             1     0030050160101         801           810
#
#       COD_STF_ARRT_STTN ZONS_ARRT  COD_ZON_PHSQ_MIN  \
# 9177      0030010711056       1                   1
# 19756     0030010057008       1                   1
# 25898               583       1                   1
# 31969     0030010733074       1                   1
# 42049     0030010733005       1                   1
# 72531               582       1                   1
#
#       DAT_DEBT_VALD_ZON_PHSQ_MIN  COD_INS_COMM   ...     COD_ZON_PHSQ_MAX  \
# 9177                  01/01/2006         75111   ...                    1
# 19756                 01/01/2006         75111   ...                    1
# 25898                 01/01/2006         75111   ...                    1
# 31969                 01/01/2006         75111   ...                    1
# 42049                 01/01/2006         75111   ...                    1
# 72531                 01/01/2006         75111   ...                    1
#
#        DAT_DEBT_VALD_ZON_PHSQ_MAX LIBL_COUR_ARRT_STTN LIBL_LONG_ARRT_STTN  \
# 9177                   01/01/2006      NATION                      NATION
# 19756                  01/01/2006      NATION - TAILL              NATION
# 25898                  01/01/2006      NATION                      NATION
# 31969                  01/01/2006      NATION                      NATION
# 42049                  01/01/2006      NATION                      NATION
# 72531                  01/01/2006      NATION                      NATION
#
#       POL_PDU       COOR_X_PHSQ       COOR_Y_PHSQ CORR_DONN_STF MOD_BUS  \
# 9177        0  604385,447126423  127604,078484772             O       1
# 19756       0  604385,447126423  127604,078484772             O       1
# 25898       0        604332,264        127458,575             O       0
# 31969       0  604422,426955433  127563,103548843             O       1
# 42049       0  604385,447126423  127604,078484772             O       1
# 72531       0        604351,955        127531,732             O       0
#
#        MOD_RER
# 9177         0
# 19756        0
# 25898        0
# 31969        0
# 42049        0
# 72531        1
#
# [6 rows x 21 columns]
