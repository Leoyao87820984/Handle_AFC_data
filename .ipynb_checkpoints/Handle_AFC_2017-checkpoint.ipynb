# %%
import pandas as pd
import numpy as np
path_arret = "F:/Stage/data/AFC/DM arret.txt"
path_mode =  "F:/Stage/data/AFC/DM mode.txt"
path_nature = "F:/Stage/data/AFC/DM nature.txt"
path_transporteur = "F:/Stage/data/AFC/DM transporteur.txt"
path_AFC = "F:/Stage/data/AFC/donnees detaillees 14 mars 2017.txt"

# %%
pd.options.display.max_rows  = 20

# %% [markdown]
# #### 1. Mode dictionnery

# %%
mode = pd.read_csv(path_mode, header = 0, delimiter="\t")
mode
# Out:
#    COD_MOD LIBL_COUR_MOD LIBL_LONG_MOD
# 0        6          TRAM    TRAMWAY T4
# 1        4          TRAM       TRAMWAY
# 2        2           BUS           BUS
# 3        3         METRO         METRO
# 4       -1            ND    NON DEFINI
# 5        1           FER         FERRE

# %% [markdown]
# #### 2. Nature dictionnery

# %%
nature = pd.read_csv(path_nature, header = 0, delimiter="\t")
nature
# Out:
#    COD_NATR_VALD COD_ENTR_SORT             LIBL_NATR_VALD  COD_MOD  \
# 0            3              3       Entree Correspondance        1
# 1            05A            1                  Entree RER        1
# 2            057            3   Sortie Correspondance RER        3
# 3            17             1                  Entree Bus        2
# 4            23             3   Sortie Correspondance RER        3
# 5            041            1              entree Tramway        4
# 6            05B            2                  Sortie RER        1
# 7            02             2                      Sortie        1
# 8            16             3          Correspondance Bus        2
# 9            01             1                      Entree       -1
# ..           ...           ...                        ...      ...
# 25           043            1         entree Tramway Sol.        4
# 26           052            2                  Sortie RER        1
# ...

# %% [markdown]
# #### 3. Arret dictionnery

# %%
arret = pd.read_csv(path_arret, header = 0, delimiter="\t", nrows = 8)
arret
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens (pandas\_libs\parsers.c:14858)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype (pandas\_libs\parsers.c:17119)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert (pandas\_libs\parsers.c:17347)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8 (pandas\_libs\parsers.c:23041)()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe8 in position 4: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-67-c73dec01fa1f> in <module>()
# ----> 1 arret = pd.read_csv(path_arret, header = 0, delimiter="\t", nrows = 8)
#       2 arret
# ...
