# %%
import  pandas as pd
import matplotlib.pyplot as plt
from IPython.display import Image

# %%
def get_counts(anything):
    counts = {}
    for a in anything:
        if  a in counts:
            counts[a] = counts[a] + 1
        else:
            counts[a] = 1
    return counts
# Out:
# {3: 1, 4: 3, 5: 5, 6: 3, 7: 2, 8: 2}

# %%
path_2 =  'F:/Stage/data/AFC/counts/counts_2'

# %%
data = pd.read_csv(path_2, delimiter="\t", header = 0, encoding="latin-1")
# Out:
# E:\python\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (6,9,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data
# Out:
#          Unnamed: 0             NUMR_CART JOUR_EXPL_VALD HEUR_VALD  \
# 0                 6  17315675668939692211     14/03/2017  09:32:06
# 1                15  52021507680586884298     14/03/2017  09:43:35
# 2                18  38108365792133058061     14/03/2017  13:36:24
# 3                25  02540310725255993356     14/03/2017  17:08:03
# 4                31  46339981807785012874     14/03/2017  20:00:02
# 5                40  95207230194591890400     14/03/2017  08:10:50
# 6                41  91199284841034032450     14/03/2017  11:37:21
# 7                42  21556462142737848654     14/03/2017  09:20:30
# 8                48  93921924610870141374     14/03/2017  16:58:50
# 9                57  26159386582907222932     14/03/2017  08:22:58
# 10               76  64419484028982370888     14/03/2017  07:44:57
# 11               77  64394047718291070921     14/03/2017  08:26:52
# 12               94  50225272701180851517     14/03/2017  20:49:34
# ...

# %%
data[data['NUMR_CART'] =='17315675668939692211' ]
# Out:
#          Unnamed: 0             NUMR_CART JOUR_EXPL_VALD HEUR_VALD  \
# 0                 6  17315675668939692211     14/03/2017  09:32:06
# 1013717     8860814  17315675668939692211     14/03/2017  21:02:15
#
#                               Lib_Arret  COD_TLB_TRNS COD_TLB_RES  \
# 0        GONCOURT (HOPITAL SAINT-LOUIS)             3           1
# 1013717            VOLTAIRE (LEON BLUM)             3         001
#
#         COD_TLB_ARRT_STTN  NUMR_BORN_VALD_EQPM COD_NATR_VALD  COD_MOD_VALD  \
# 0           0030030080500                  103            31             3
# 1013717     0030030240100                  102            31             3
#
#          COD_STF_TRNS COD_STF_RES COD_STF_LIGN
# 0                 100         110          ND
# 1013717           100         110          ND

# %%
Image('E:/Study/id_1.PNG')

# %%
data[data['NUMR_CART'] == '52021507680586884298']
# Out:
#         Unnamed: 0             NUMR_CART JOUR_EXPL_VALD HEUR_VALD  \
# 1               15  52021507680586884298     14/03/2017  09:43:35
# 486577     4792055  52021507680586884298     14/03/2017  11:34:20
#
#                     Lib_Arret  COD_TLB_TRNS COD_TLB_RES COD_TLB_ARRT_STTN  \
# 1       NOTRE-DAME-DES-CHAMPS             3           1     0030030041400
# 486577           MONTPARNASSE             3         001     0030030040800
#
#         NUMR_BORN_VALD_EQPM COD_NATR_VALD  COD_MOD_VALD  COD_STF_TRNS  \
# 1                       103            31             3           100
# 486577                  334            31             3           100
#
#        COD_STF_RES COD_STF_LIGN
# 1              110          ND
# 486577         110          ND

# %%
Image('E:/Study/id_2.PNG')
