# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime, timedelta

# %%
speeds = {1 : 6.9, 3 : 4.6, 4 :3,6 : 3,  2: 2, -1:2}

# %%
speeds[1]
# Out:
# 6.9

# %%
path_1 = 'E:/Study/data/1_0.csv'
path_2 = 'E:/Study/data/2_0.csv'
path_3 = 'E:/Study/data/3_0.csv'
path_4 = 'E:/Study/data/4_0.csv'
path_5 = 'E:/Study/data/5_0.csv'
path_6 = 'E:/Study/data/6_0.csv'
path_7 = 'E:/Study/data/7_0.csv'
path_arret = "F:/Stage/data/AFC/DM arret.txt"

# %%
def get_counts(anything):
    counts = {}
    for a in anything:
        if a in counts:
            counts[a] = counts[a] + 1
        else:
            counts[a] = 1
    return counts

# %%
def get_median(data):
    data.sort()
    half = len(data) // 2
    return (data[half] + data[~half]) / 2

# %%
def speed(data):
    v = int(np.sqrt((data['D_x'] - data['O_x'])**2 + (data['D_y'] - data['O_y'])**2 )) / ((data['Dt'] - data['Ot']).seconds+1)
    return v

# %%
def change_Ot_time(data):
    return timedelta(hours=int(data['Ot'][6:9]) , minutes = int(data['Ot'][10:12]), seconds = int(data['Ot'][13:15]))
def change_Dt_time(data):
    if pd.isnull(data['Dt']):
        return timedelta(seconds = 0)
    else:
        return timedelta(hours=int(data['Dt'][6:9]) , minutes = int(data['Dt'][10:12]), seconds = int(data['Dt'][13:15]))

# %%
def time_prediction(data):
    if data['unkonwn'] == 'no':
        return data['Dt']
    else:
        s = int(np.sqrt((data['D_x'] - data['O_x'])**2 + (data['D_y'] - data['O_y'])**2 )) 
        v = speeds[data['O_mode']]
        t = timedelta(seconds = int(s/v) )
        return data['Ot'] + t

# %%
def get_time_sep(data):
    for i in range(len(data)):
        
        


test1 = [(x.iloc[1]['Ot'].seconds - x.iloc[0]['Dt'].seconds)/60, x.iloc[0]['O_mode'], x.iloc[0]['D_mode']]
test2 = [(x.iloc[2]['Ot'].seconds - x.iloc[1]['Dt'].seconds)/60, x.iloc[1]['O_mode'], x.iloc[1]['D_mode']]
print(test1)
print(test2)

# %%
data_1 = pd.read_csv(path_1, header=0, delimiter="\t", encoding='latin-1')
data_2 = pd.read_csv(path_2, header=0, delimiter="\t", encoding='latin-1')
data_3 = pd.read_csv(path_3, header=0, delimiter="\t", encoding='latin-1')
data_4 = pd.read_csv(path_4, header=0, delimiter="\t", encoding='latin-1')
data_5 = pd.read_csv(path_5, header=0, delimiter="\t", encoding='latin-1')
data_6 = pd.read_csv(path_6, header=0, delimiter="\t", encoding='latin-1')
data_7 = pd.read_csv(path_7, header=0, delimiter="\t", encoding='latin-1')

# %%
arrets = pd.read_csv(path_arret, header=0, delimiter="\t", encoding='latin-1')

# %%
data_2
# Out:
#         Unnamed: 0  trip_id             client_id        date  \
# 0                0        0  99999910079519014654  14/03/2017
# 1                1        1  99999910079519014654  14/03/2017
# 2                2        3  99999834312022823315  14/03/2017
# 3                3        4  99999641142476692661  14/03/2017
# 4                4        5  99999641142476692661  14/03/2017
# 5                5        6  99999341872786484931  14/03/2017
# 6                6        7  99999341872786484931  14/03/2017
# 19      596763.0  131694.0        3  594102.0  133828.0       2       2
# 20      594102.0  133828.0        2  596763.0  131694.0       2       2
# 21      599977.0  129903.0        3  594344.0  135948.0       3       1
# 22      602939.0  130156.0        1  601721.0  132228.0       3       3
# 23      601721.0  132228.0        1  602939.0  130156.0       3       3
# 24      571386.0  123022.0        5  572173.0  124866.0       2       2
# 25      572173.0  124866.0        5  571386.0  123022.0       2       2
# 26      617876.0  126963.0        4  594293.0  113752.0       1       1
# 27      594293.0  113752.0        4  617876.0  126963.0       1       1
# 28      601019.0  125478.0        1  601669.0  124324.0       3       2
# 29      601669.0  124324.0        1  601019.0  125478.0       2       3
# ...          ...       ...      ...       ...       ...     ...     ...
# 112793  604826.0  132312.0        1  603747.0  129134.0       3       3
# 112794  603747.0  129134.0        2  604826.0  132312.0       3       3
# 112795  597862.0  127400.0        1  602103.0  126885.0       3       3
# 112796  602103.0  126885.0        1  597862.0  127400.0       3       3
# 112797  607210.0  101657.0        5  607113.0  104279.0       2       2
# 112798  607113.0  104279.0        5  607210.0  101657.0       2       2
# 112799  600040.0  131342.0        2  595244.0  131196.0       3       3
# 112800  595244.0  131196.0        1  600040.0  131342.0       3       3
# 112801  603372.0  132712.0        2  604087.0  133705.0       3       3
# 112802  604087.0  133705.0        1  603372.0  132712.0       3       3
# 112803  599444.0  132994.0        1  602879.0  125501.0       3       3
# 112804  602879.0  125501.0        1  599444.0  132994.0       3       3
# 112805  597724.0  125257.0        1  598381.0  130369.0       3       3
# 112806  598381.0  130369.0        1  597724.0  125257.0       3       3
# 112807  592703.0  132422.0        3  592703.0  132422.0       1       1
# 112808  592703.0  132422.0        3  592703.0  132422.0       1       1
# 112809  598881.0  131309.0        1  599667.0  130060.0       3       3
# 112810  599667.0  130060.0        1  598881.0  131309.0       3       3
# 112811  599009.0  125400.0        1  602874.0  125514.0       2       2
# 112812  602874.0  125514.0        1  599009.0  125400.0       2       2
# 112813  574349.0  120575.0        5  575719.0  119365.0       2       2
# 112814  575719.0  119365.0        5  574349.0  120575.0       2       2
# 112815  602056.0  124376.0        1  599667.0  130060.0       3       3
# 112816  599667.0  130060.0        1  602056.0  124376.0       3       3
# 112817  601915.0  135300.0        2  601016.0  135239.0       1       1
# 112818  601016.0  135239.0        2  601915.0  135300.0       1       1
# 112819  597133.0  133024.0        2  592238.0  125471.0       1       3
# 112820  592238.0  125471.0        2  597133.0  133024.0       3       1
# 112821  598645.0  125939.0        1  596409.0  129240.0       3       3
# 112822  596409.0  129240.0        1  598645.0  125939.0       3       3
#
# [112823 rows x 12 columns]

# %%
list_data = [data_2, data_3, data_4, data_5, data_6, data_7]

# %%
finall_result = pd.concat(list_data, axis=0, ignore_index=True)

# %%
finall_result.drop('Unnamed: 0', axis=1, inplace=True)

# %%
zones_2 = finall_result[finall_result['O_zones'] == 2]

# %%
zones_1 = finall_result[finall_result['O_zones'] == 1]

# %%
zones_3 = finall_result[finall_result['O_zones'] == 3]

# %%
zones_4 = finall_result[finall_result['O_zones'] == 4]

# %%
zones_5 = finall_result[finall_result['O_zones'] == 5]

# %%
zones_1_counts = get_counts(zones_1['D_zones'])
x = zones_1_counts.keys()
y = zones_1_counts.values()
plt.figure(figsize=(15,5))
plt.bar(np.arange(len(x)) , y)
plt.xticks(np.arange(len(x)), x, rotation = 90)
plt.xlabel('zones')
plt.ylabel('counts')
plt.legend(['Zones_1'])
plt.show()
zones_2_counts = get_counts(zones_2['D_zones'])
x = zones_2_counts.keys()
y = zones_2_counts.values()
plt.figure(figsize=(15,5))
plt.bar(np.arange(len(x)) , y)
plt.xticks(np.arange(len(x)), x, rotation = 90)
plt.xlabel('zones')
plt.ylabel('counts')
plt.legend(['Zones_2'])
plt.show()
zones_3_counts = get_counts(zones_3['D_zones'])
x = zones_3_counts.keys()
y = zones_3_counts.values()
plt.figure(figsize=(15,5))
plt.bar(np.arange(len(x)) , y)
plt.xticks(np.arange(len(x)), x, rotation = 90)
plt.xlabel('zones')
plt.ylabel('counts')
plt.legend(['Zones_3'])
plt.show()
zones_4_counts = get_counts(zones_4['D_zones'])
x = zones_4_counts.keys()
y = zones_4_counts.values()
plt.figure(figsize=(15,5))
plt.bar(np.arange(len(x)) , y)
plt.xticks(np.arange(len(x)), x, rotation = 90)
plt.xlabel('zones')
plt.ylabel('counts')
plt.legend(['Zones_4'])
plt.show()
zones_5_counts = get_counts(zones_5['D_zones'])
x = zones_5_counts.keys()
y = zones_5_counts.values()
plt.figure(figsize=(15,5))
plt.bar(np.arange(len(x)) , y)
plt.xticks(np.arange(len(x)), x, rotation = 90)
plt.xlabel('zones')
plt.ylabel('counts')
plt.legend(['Zones_5'])
plt.show()

# %%
get_counts(finall_result['O_mode'])
# Out:
# {-1: 3, 1: 208672, 2: 207815, 3: 309919, 4: 24157, 6: 623}

# %%
x = data_2.loc[:10]
a = x.loc[1]['Dt']
pd.isnull(a)
# Out:
# True

# %%
finall_result['Ot'] = finall_result.apply(change_Ot_time, axis=1)
finall_result['Dt'] = finall_result.apply(change_Dt_time, axis=1)

# %%
data_no = finall_result[finall_result['unkonwn'] == 'no']

# %%
data_no.apply(speed, axis=1)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-179-6965a522221b> in <module>()
# ----> 1 data_no.apply(speed, axis=1)
#
# E:\python\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4260                         f, axis,
#    4261                         reduce=reduce,
# -> 4262                         ignore_failures=ignore_failures)
#    4263             else:
#    4264                 return self._apply_broadcast(f, axis)
#
# E:\python\lib\site-packages\pandas\core\frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4356             try:
#    4357                 for i, v in enumerate(series_gen):
# -> 4358                     results[i] = func(v)
#    4359                     keys.append(v.name)
#    4360             except Exception as e:
#
# <ipython-input-177-161876c87286> in speed(data)
#       1 def speed(data):
# ----> 2     v = int(np.sqrt((data['D_x'] - data['O_x'])**2 + (data['D_y'] - data['O_y'])**2 )) / (data['Dt'] - data['Ot']).seconds
#       3     return v
#
# ZeroDivisionError: ('division by zero', 'occurred at index 356400')

# %%
speed(x)
# Out:
# 5.482415394824154

# %%
data_no['speed'] = data_no.apply(speed, axis=1)
# Out:
# E:\python\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
no_speed = data_no['speed']
no_speed.get_values()
y = [a for a in  no_speed.get_values() if (a<50 and a>0)]

# %%
for a in no_speed.get_values():
    if a > 50:
        print(a)
# Out:
# 179.0
# 141.5
# 96.7142857143
# 60.0535714286
# 206.75
# 67.26
# 54.8221258134
# 60.0535714286
# 147.271428571
# 962.0
# 148.361111111
# 85.5
# 59.5714285714
# 67.2291666667
# 126.857142857
# 73.5161290323
# 159.829457364
# 103.859594384
# 206.75
# 77.7898383372
# 58.64
# 91.0
# 72.0
# 75.4094488189
# 68.0

# %%
get_median(y)
# Out:
# 6.9222972972972974

# %%
plt.plot(y)
plt.show()

# %%
finall_result['Dt'] = finall_result.apply(time_prediction, axis=1)

# %%
id_s = [a[0] for a in get_counts(finall_result['client_id']).items()]

# %%
finall_result
# Out:
#         Unnamed: 0  trip_id             client_id        date  \
# 0                0        0  99999910079519014654  14/03/2017
# 1                1        1  99999910079519014654  14/03/2017
# 2                2        3  99999834312022823315  14/03/2017
# 3                3        4  99999641142476692661  14/03/2017
# 4                4        5  99999641142476692661  14/03/2017
# 5                5        6  99999341872786484931  14/03/2017
# 6                6        7  99999341872786484931  14/03/2017
# 7                7        8  99999319654609556985  14/03/2017
# 8                8        9  99999319654609556985  14/03/2017
# 9                9       10  99999279653049637534  14/03/2017
# 10              10       11  99999279653049637534  14/03/2017
# 11              11       13  99999206973859506317  14/03/2017
# 12              12       14  99999206973859506317  14/03/2017
# 13              13       15  99999010865143272586  14/03/2017
# 14              14       16  99999010865143272586  14/03/2017
# 15              15       17  99998956624718552818  14/03/2017
# 16              16       18  99998956624718552818  14/03/2017
# 17              17       20  99998699026613170093  14/03/2017
# 18              18       21  99998699026613170093  14/03/2017
# 19              19       22  99998501482912656386  14/03/2017
# 20              20       23  99998501482912656386  14/03/2017
# 21              21       24  99998475840156675293  14/03/2017
# 22              22       28  99997610749800824122  14/03/2017
# 23              23       29  99997610749800824122  14/03/2017
# 24              24       30  99997027099510187434  14/03/2017
# 25              25       31  99997027099510187434  14/03/2017
# 26              26       33  99996834670456162891  14/03/2017
# 27              27       34  99996834670456162891  14/03/2017
# 28              28       35  99996683905082603872  14/03/2017
# 29              29       36  99996683905082603872  14/03/2017
# ...            ...      ...                   ...         ...
# 751159       91252    42675  90057503943197069835  14/03/2017
# 751160       91253    42675  90057503943197069835  14/03/2017
# 751161       91254    42675  90057503943197069835  14/03/2017
# 751162       91255    42676  90056955132722572201  14/03/2017
# 751163       91256    42676  90056955132722572201  14/03/2017
# 751164       91257    42676  90056955132722572201  14/03/2017
# 751165       91258    42677  90056955132722572201  14/03/2017
# 751166       91259    42677  90056955132722572201  14/03/2017
# 751167       91260    42677  90056955132722572201  14/03/2017
# 751168       91261    42678  90056385889504155546  14/03/2017
# 751169       91262    42678  90056385889504155546  14/03/2017
# 751170       91263    42678  90056385889504155546  14/03/2017
# 751171       91264    42679  90056385889504155546  14/03/2017
# 751172       91265    42679  90056385889504155546  14/03/2017
# 751173       91266    42680  90056239080434716098  14/03/2017
# 751174       91267    42680  90056239080434716098  14/03/2017
# 751170  30050091300   ...      ND        d       1  602696.0  127075.0
# 751171  30050091300   ...      ND       no       1  602696.0  127075.0
# 751172  30050091300   ...      ND       no       1  602696.0  127075.0
# 751173  30010303061   ...      303       d       4  611676.0  132086.0
# 751174       113407   ...      ND       no       3  610504.0  132630.0
# 751175  30010026023   ...      26        d       1  601385.0  131051.0
# 751176  30030110800   ...      ND        d       1  601025.0  129968.0
# 751177       281899   ...      ND       no       1  599280.0  130509.0
# 751178  30030220900   ...      ND        d       1  601757.0  131551.0
# 751179  30050170101   ...      ND       no       1  596916.0  130422.0
# 751180  30050170502   ...      ND       no       3  591108.0  133465.0
# 751181  30050170401   ...      ND        d       3  592703.0  132422.0
# 751182  30050170101   ...      ND       dh       1  596916.0  130422.0
# 751183       113845   ...      ND        d       3  611941.0  132465.0
# 751184       281899   ...      ND        d       1  599280.0  130509.0
# 751185  30050060600   ...      ND       no       1  599516.0  130190.0
# 751186  30050170401   ...      ND        d       3  592703.0  132422.0
# 751187  30050060600   ...      ND        d       1  599516.0  130190.0
# 751188       281899   ...      ND       dh       1  599280.0  130509.0
#
#         D_zones       D_x       D_y  O_mode  D_mode
# 0             5  578838.0  121777.0       2       2
# 1             4  585747.0  123471.0       2       2
# 2             1  601452.0  131164.0       1       1
# 3             1  600271.0  127357.0       2       2
# 4             1  599470.0  125555.0       2       2
# 5             1  603698.0  131856.0       3       3
# 6             1  597767.0  128247.0       3       3
# 7             1  601933.0  125860.0       3       3
# 8             1  600044.0  125824.0       3       3
# 9             1  600042.0  126617.0       1       1
# 10            5  617179.0  103107.0       1       1
# 11            1  599965.0  129125.0       2       2
# 12            1  599276.0  125211.0       2       2
# 13            1  595205.0  126400.0       4       4
# 14            1  602018.0  124363.0       4       4
# 15            1  602152.0  131538.0       3       3
# 16            1  597071.0  126315.0       3       3
# 17            3  609027.0  119938.0       3       3
# 18            1  604582.0  129386.0       3       3
# 19            3  594102.0  133828.0       2       2
# 20            2  596763.0  131694.0       2       2
# 21            3  594344.0  135948.0       3       1
# 22            1  601721.0  132228.0       3       3
# 23            1  602939.0  130156.0       3       3
# 24            5  572173.0  124866.0       2       2
# 25            5  571386.0  123022.0       2       2
# 26            4  594293.0  113752.0       1       1
# 27            4  617876.0  126963.0       1       1
# 28            1  601669.0  124324.0       3       2
# 29            1  601019.0  125478.0       2       3
# ...         ...       ...       ...     ...     ...
# 751159        1  602696.0  127075.0       3       1
# 751160        1  602696.0  127075.0       1       1
# 751161        6  623522.0   91884.0       1       1
# 751162        5  598247.0  105798.0       2       1
# 751163        1  602121.0  126895.0       1       1
# 751164        1  594856.0  127195.0       3       3
# 751165        1  602121.0  126895.0       3       1
# 751166        4  601053.0  108197.0       1       2
# 751167        5  599846.0  102545.0       2       2
# 751168        4  586754.0  131657.0       2       1
# 751169        1  602696.0  127075.0       1       3
# 751170        1  602696.0  127075.0       3       1
# 751171        1  602696.0  127075.0       1       1
# 751172        4  586754.0  131657.0       1       1
# 751173        3  610504.0  132630.0       2       1
# 751174        1  601636.0  131163.0       1       1
# 751175        1  601025.0  129968.0       2       3
# 751176        1  599280.0  130509.0       3       1
# 751177        4  612909.0  132086.0       1       1
# 751178        1  596916.0  130422.0       3       1
# 751179        3  591108.0  133465.0       1       1
# 751180        3  592703.0  132422.0       1       1
# 751181        1  596916.0  130422.0       1       3
# 751182        1  601757.0  131551.0       3       3
# 751183        1  599280.0  130509.0       6       3
# 751184        1  599516.0  130190.0       3       1
# 751185        3  592703.0  132422.0       1       1
# 751186        1  599516.0  130190.0       1       3
# 751187        1  599280.0  130509.0       3       1
# 751188        3  611941.0  132465.0       1       6
#
# [751189 rows x 21 columns]

# %%
x = finall_result[finall_result['client_id'] == id_s[109003]]

# %%
x
# Out:
#         Unnamed: 0  trip_id             client_id        date  \
# 262479       40088    25885  97595946228024322255  14/03/2017
# 262480       40089    25885  97595946228024322255  14/03/2017
# 262481       40090    25886  97595946228024322255  14/03/2017
#
#                              O                       D       Ot       Dt  \
# 262479               CIMETIERE                  DOMONT 07:48:00 08:00:32
# 262480                  DOMONT  HAUSSMANN-SAINT-LAZARE 07:56:54 08:35:34
# 262481  HAUSSMANN-SAINT-LAZARE               CIMETIERE 17:59:04 18:38:43
#
#         mode  O_station   ...    ligne unkonwn O_zones       O_x       O_y  \
# 262479    16        277   ...      13        d       4  599048.0  146925.0
# 262480     2     276436   ...      ND       no       4  600022.0  148072.0
# 262481     2     281899   ...      ND       dh       1  599280.0  130509.0
#
#         D_zones       D_x       D_y  O_mode  D_mode
# 262479        4  600022.0  148072.0       2       1
# 262480        1  599280.0  130509.0       1       1
# 262481        4  599048.0  146925.0       1       2
#
# [3 rows x 21 columns]

# %%
test1 = [(x.iloc[1]['Ot'].seconds - x.iloc[0]['Dt'].seconds)/60, x.iloc[0]['O_mode'], x.iloc[0]['D_mode']]
test2 = [(x.iloc[2]['Ot'].seconds - x.iloc[1]['Dt'].seconds)/60, x.iloc[1]['O_mode'], x.iloc[1]['D_mode']]
print(test1)
print(test2)
# Out:
# [-3.6333333333333333, 2, 1]
# [563.5, 1, 1]

# %%
O_counts = get_counts(test_RER['O'])
O_counts = sorted(O_counts.items(), key = lambda item:item[1], reverse=True)
len(O_counts)
# Out:
# 46

# %%
rer_A = finall_result[finall_result['mode'] == 801]

# %%
len(get_counts(rer_A['O']))
# Out:
# 46

# %%
get_counts(rer_A['D'])
# Out:
# {'MASSY-PALAISEAU': 268,
#  'SAVIGNY-LE-TEMPLE-NANDY': 151,
#  'BERAULT-METRO': 7,
#  'PONT DE NEUILLY (AVENUE DE MADRID)': 168,
#  'LA DEFENSE-GRANDE ARCHE': 6662,
#  'JUZIERS': 5,
#  'BALLANCOURT': 9,
#  'NOGENT-SUR-MARNE': 486,
#  'SAINT-GEORGES - CHATEAUDUN': 4,
#  'CONVENTION': 50,
#  'POISSY': 567,
#  'CHATOU-CROISSY': 427,
#  'MAULE': 1,
#  'HOUILLES-CARRIERES-SUR-SEINE': 760,
#  'ROISSY-EN-BRIE': 66,
#  'PICPUS': 51,
#  'Lovr-Bruxell': 1,
#  'OLYMPIADES': 358,
#  'SAINT-GERMAIN-DES-PRES': 23,
#  'GRANDS BOULEVARDS (RUE MONTMARTRE)': 124,
#  'MELUN': 28,
#  "Gare d'Aulnay sous Bois": 28,
#  'NANTERRE-PREFECTURE': 1208,
#  'LE VESINET-LE PECQ': 382,
#  'STADE LEO LAGRANGE': 1,
#  'CERGY LE HAUT': 585,
#  'SARTROUVILLE': 793,
#  'NATION': 3856,
#  'CITE UNIVERSITAIRE': 254,
#  'LA PLAINE-STADE DE FRANCE': 291,
#  'LE PELETIER': 78,
#  'CHATELET-LES HALLES': 3403,
#  'PANTIN': 52,
#  'BIBLIOTHEQUE FRANCOIS MITTERRAND': 957,
#  'COMBS-LA-VILLE-QUINCY': 139,
#  'GARE DE LYON': 6015,
#  'LES BOULLEREAUX-CHAMPIGNY': 51,
#  'PORTE DES LILAS': 70,
#  'NEUILLY-PLAISANCE': 874,
#  'CAMBRONNE': 75,
#  'RUEIL-MALMAISON': 1257,
#  'GARE DU NORD': 963,
#  'JOINVILLE-LE-PONT': 650,
#  'Aérospatiale': 1,
#  'LA VARENNE-CHENNEVIERES': 374,
#  "CHAMP DE COURSES D'ENGHIEN": 12,
#  'DUPLEIX': 103,
#  "CONFLANS-FIN-D'OISE": 254,
#  'BOISSIERE': 78,
#  'BOURG-LA-REINE': 248,
#  'AUBER': 4783,
#  'TORCY': 651,
#  'MADELEINE': 290,
#  'CAMELIAS': 8,
#  'VINCENNES': 1453,
#  'VAL-DE-FONTENAY': 1459,
#  "PORTE D'ORLEANS": 17,
#  'CHESSY - MARNE-LA-VALLEE': 566,
#  'JEAN JAURES': 3,
#  'PONT DE LEVALLOIS-BECON': 151,
#  'LE MEE': 46,
#  'GENTILLY': 149,
#  'STADE DE FRANCE-SAINT-DENIS': 428,
#  'CHATEAU DE VINCENNES': 41,
#  'DENFERT-ROCHEREAU': 252,
#  'COMMERCE': 63,
#  'SAINT-GERMAIN-EN-LAYE': 840,
#  'PROGRES - ARNAUD CARREL': 7,
#  'ESSONNES-ROBINSON': 6,
#  'LOGNES': 317,
#  'CHAMPIGNY': 577,
#  'PORT ROYAL': 199,
#  'PONTOISE': 10,
#  'CHAMPS-ELYSEES-CLEMENCEAU': 84,
#  'MAIRIE DE CLICHY': 92,
#  'BOIS-COLOMBES': 39,
#  'BOBIGNY-PABLO PICASSO': 21,
#  'SEVRES-BABYLONE': 37,
#  "VAL-D'EUROPE": 731,
#  'AVENUE DU CHATEAU': 4,
#  'LE VESINET-CENTRE': 241,
#  'SAINTE-GENEVIEVE': 1,
#  'LA TOUR MAUBOURG': 41,
#  'ARGENTINE': 89,
#  'FONTENAY-SOUS-BOIS': 496,
#  "PORTE D'ITALIE": 20,
#  'LES VALLEES': 59,
#  'BRY-SUR-MARNE': 396,
#  'BROCHANT': 28,
#  'SAINT-FRANCOIS-XAVIER': 23,
#  'LES SABLONS': 3,
#  'CHARLES DE GAULLE ETOILE': 4185,
#  'BAGNEUX': 131,
#  'AEROPORT CHARLES DE GAULLE 1': 70,
#  'BOISSY-SAINT-LEGER': 478,
#  'NOISY-CHAMPS': 1053,
#  'LA GARENNE-COLOMBES': 69,
#  'SAINT-DENIS-PORTE DE PARIS': 8,
#  'BASTILLE': 250,
#  'BUSSY-SAINT-GEORGES': 593,
#  'CERGY-PREFECTURE': 1053,
#  'ESPLANADE DE LA DEFENSE': 257,
#  'LUXEMBOURG': 447,
#  'Gare Sud départ': 37,
#  'PORTE MAILLOT': 247,
#  'SARCELLES-SAINT-BRICE': 43,
#  'OPERA': 344,
#  'RUE DE LA POMPE (AVENUE GEORGES MANDEL)': 46,
#  'ROBESPIERRE': 132,
#  'MONTPARNASSE': 189,
#  'BASILIQUE DE SAINT-DENIS': 23,
#  'REUILLY-DIDEROT': 239,
#  'JULES QUENTIN': 2,
#  'AULNAY-SOUS-BOIS': 199,
#  'TUILERIES': 63,
#  'ACHERES-VILLE': 112,
#  "NOISY-LE-GRAND-MONT D'EST": 1374,
#  'GARIBALDI': 40,
#  'MAISONS-LAFFITTE': 450,
#  'CHOISY-LE-ROI': 14,
#  "LES SABLONS (JARDIN D'ACCLIMATATION)": 189,
#  'COLONEL FABIEN': 83,
#  'GRIGNY-CENTRE': 129,
#  'NANTERRE-UNIVERSITE': 732,
#  'VITRY-SUR-SEINE': 10,
#  'RANELAGH': 27,
#  'AEROPORT CHARLES DE GAULLE 2-TGV': 56,
#  'AUBERVILLIERS-PANTIN (QUATRE CHEMINS)': 50,
#  'NOTRE-DAME-DES-CHAMPS': 13,
#  'NOISY-LE-SEC': 74,
#  'SENTIER': 35,
#  'MONCEAU': 56,
#  'EVRY-COURCOURONNES': 233,
#  'LE PARC-DE-SAINT-MAUR': 459,
#  'SAINT-DENIS': 374,
#  'SAINT-DENIS-UNIVERSITE': 49,
#  'HAUSSMANN-SAINT-LAZARE': 490,
#  'SAINT-LAZARE': 973,
#  'ARTS ET METIERS': 49,
#  'BEL-AIR': 95,
#  'NANTERRE-VILLE': 647,
#  'NOISIEL': 490,
#  'TOLBIAC': 33,
#  'MEULAN-HARDRICOURT': 7,
#  'JULES JOFFRIN': 27,
#  'ROSNY-SOUS-BOIS': 103,
#  'ANTONY': 245,
#  'VILLEPARISIS-MITRY-LE-NEUF': 69,
#  'PASTEUR': 116,
#  'CHATELET': 209,
#  'PYRAMIDES': 275,
#  'SAINT-MAUR-CRETEIL': 545,
#  'YERRES': 157,
#  'LA MOTTE-PICQUET-GRENELLE': 103,
#  'MICHEL-ANGE-AUTEUIL': 28,
#  'BIR-HAKEIM (GRENELLE)': 119,
#  'BALZAC': 6,
#  'OURCQ': 30,
#  'CERGY-SAINT-CHRISTOPHE': 480,
#  'MONTIGNY-BEAUCHAMP': 14,
#  'PLACE DE CLICHY': 113,
#  'BARBES-ROCHECHOUART': 61,
#  'PERNETY': 23,
#  'HOTEL DE VILLE': 210,
#  'PIERREFITTE-STAINS': 200,
#  'POISSONNIERE': 80,
#  'VILLIERS': 122,
#  'LES GRESILLONS RER': 1,
#  'SAINT-MANDE-TOURELLE': 232,
#  'MAIRIE DE SAINT-OUEN': 40,
#  'LES COQUETIERS': 3,
#  'FRANCONVILLE-LE-PLESSIS-BOUCHARD': 36,
#  'VILLEJUIF-LOUIS ARAGON': 74,
#  'TROCADERO': 122,
#  'VICTOR HUGO': 155,
#  'SAINT-JACQUES': 15,
#  'QUATRE SEPTEMBRE': 72,
#  'CRIMEE': 59,
#  'GOUSSAINVILLE': 101,
#  'IENA': 29,
#  'SAINT-PAUL (LE MARAIS)': 154,
#  'BOIS PERRIER-RER-ROSNY 2                ': 10,
#  'TOURNAN': 17,
#  'CHATILLON-MONTROUGE': 50,
#  'SUCY-BONNEUIL': 338,
#  'PLAISANCE': 48,
#  "GARE DE L'EST": 91,
#  'NEUVILLE UNIVERSITE': 147,
#  'SAINT-AUGUSTIN': 105,
#  'BECON-LES-BRUYERES': 83,
#  'HOTEL DE VILLE DE BOIS-COLOMBES': 1,
#  'PORTE DE PANTIN': 13,
#  'PORTE DE VINCENNES': 173,
#  'ERMONT-EAUBONNE': 60,
#  'PALAISEAU-VILLEBON': 27,
#  'MAISONS-ALFORT-ALFORTVILLE': 242,
#  'PALAISEAU': 28,
#  'VILLEJUIF-LEO LAGRANGE': 50,
#  'GUY MOQUET': 54,
#  'LIEUSAINT-MOISSY': 153,
#  'ARGENTEUIL': 52,
#  'LES AGNETTES-ASNIERES-GENNEVILLIERS': 15,
#  'LA COURNEUVE-AUBERVILLIERS': 121,
#  'DRANCY': 89,
#  "FORT D'AUBERVILLIERS": 23,
#  'LAMARCK-CAULAINCOURT': 28,
#  'VILLIERS-SUR-MARNE-PLESSIS-TREVISE': 97,
#  'STALINGRAD': 59,
#  'VERT-GALANT': 108,
#  'ROME': 54,
#  'PASSY': 90,
#  'ANATOLE FRANCE': 96,
#  'FRANKLIN-D.ROOSEVELT': 285,
#  'CLICHY-LEVALLOIS': 103,
#  'LOUVRE-RIVOLI': 22,
#  'PORTE DE LA CHAPELLE': 10,
#  'ARCUEIL-CACHAN': 167,
#  'SAINT-MICHEL NOTRE DAME': 233,
#  'ALESIA': 12,
#  'SAINT-GEORGES': 16,
#  "MAIRIE D'ISSY": 25,
#  'GAGNY': 23,
#  'GARE DE COLOMBES': 4,
#  'ROSNY-BOIS-PERRIER': 67,
#  'BLANCHE': 30,
#  'CONCORDE': 96,
#  'ASNIERES': 35,
#  'MITRY-CLAYE': 24,
#  'VIGNEUX-SUR-SEINE': 175,
#  'ABBESSES': 11,
#  'BRUNOY': 222,
#  'BOUFFEMONT-MOISSELLES': 10,
#  'LE VERT-DE-MAISONS': 148,
#  'LES HALLES': 127,
#  'CENSIER-DAUBENTON': 93,
#  'ARMORIQUE-MUSEE POSTAL                  ': 1,
#  'CHAVILLE-VELIZY': 1,
#  'NOGENT-LE-PERREUX': 63,
#  'ENGHIEN-LES-BAINS': 46,
#  'CHARDON-LAGACHE': 8,
#  "CHATEAU D'EAU": 9,
#  'PYRENEES': 54,
#  'COURCELLES': 122,
#  'ECOLE VETERINAIRE DE MAISONS-ALFORT': 38,
#  'BREGUET-SABIN': 25,
#  'ANVERS': 43,
#  'MANTES-LA-JOLIE': 10,
#  'MALAKOFF-RUE ETIENNE DOLET': 25,
#  'GEORGE V': 133,
#  'MENIL': 1,
#  'NEUVILLE RER': 68,
#  'MAGENTA': 69,
#  'ROND-POINT DES PYRAMIDES': 2,
#  'MAIRIE DE COLOMBES': 2,
#  'SAINT GERMAIN-ODEON                     ': 1,
#  'TELEGRAPHE': 50,
#  "PORTE D'ORLEANS-METRO": 6,
#  'COUR SAINT-EMILION': 288,
#  'PONT-NEUF (LA MONNAIE)': 8,
#  'LES MUREAUX': 67,
#  'CRETEIL-UNIVERSITE': 23,
#  'LE BOURGET': 169,
#  'LES BACONNETS': 101,
#  'Montereau SNCF': 2,
#  'LA CROIX-DE-BERNY-FRESNES': 98,
#  'STRASBOURG-SAINT-DENIS': 50,
#  'LE RAINCY-VILLEMOMBLE-MONTFERMEIL': 30,
#  'J. Jaurès': 1,
#  'MIROMESNIL': 141,
#  'BELLEVILLE': 155,
#  'GARE DE MAISONS-LAFFITTE-RER': 10,
#  'ORSAY-VILLE': 39,
#  'MARCEL SEMBAT': 82,
#  'BOUSSY-SAINT-ANTOINE': 137,
#  'HAVRE-CAUMARTIN': 54,
#  'GABRIEL PERI-ASNIERES-GENNEVILLIERS': 42,
#  'ALEXANDRE DUMAS': 114,
#  'Commissariat': 6,
#  'PALAIS ROYAL-MUSEE DU LOUVRE': 105,
#  'SEVRES-LECOURBE': 48,
#  'LA COURNEUVE 8 MAI 1945': 34,
#  'AUSTERLITZ': 59,
#  'JEAN-PIERRE TIMBAUD': 2,
#  'ROND-POINT DES CHAMPS-ELYSEES': 7,
#  'VILLIERS-SUR-MARNE-LE PLESSIS-TREVISE RER': 3,
#  'FELIX FAURE': 50,
#  'Médiathèque': 1,
#  'Lycée Alain': 1,
#  'MARAICHERS': 101,
#  'VERDUN': 4,
#  'Gare RER Cergy Préfecture': 4,
#  'BALARD': 110,
#  'IVRY-SUR-SEINE': 25,
#  'RUE DU BAC': 40,
#  'LA FOURCHE': 32,
#  'GAITE': 20,
#  'LIBERTE': 32,
#  'LOUISE MICHEL': 107,
#  'PORTE DE VANVES': 36,
#  '              Neuville-sur-Oise Gare RER': 1,
#  'LES COURTILLES': 24,
#  'CARREFOUR PLEYEL': 36,
#  'MENILMONTANT': 65,
#  'MARCADET-POISSONNIERS': 22,
#  'PORTE DE CHAMPERRET': 58,
#  'CHARLES MICHELS': 48,
#  'MALESHERBES': 68,
#  'RD 7 - PONT DE NEUILLY': 2,
#  "PLACE D'ITALIE": 112,
#  'LE GRILLON': 3,
#  'VOLONTAIRES': 11,
#  'SAINT-SEBASTIEN FROISSART': 22,
#  'BERNAU DOLET': 1,
#  'GARE DE SAINT GERMAIN EN LAYE': 12,
#  'JUVISY': 134,
#  'LE KREMLIN-BICETRE': 69,
#  'JAURES': 52,
#  'ROISSYPOLE': 2,
#  'MASSY-VERRIERES': 14,
#  'BOURSE': 112,
#  'LA DEFENSE-RER                          ': 8,
#  'CERNAY': 14,
#  'PORTE DE SAINT-CLOUD': 56,
#  'GARE DE LA C': 6,
#  'VAUGIRARD (ADOLPHE CHERIOU)': 43,
#  'NORMANDIE': 1,
#  'DEUIL-MONTMAGNY': 22,
#  'CROIX DE CHAVAUX (JACQUES DUCLOS)': 114,
#  'VERNOUILLET-VERNEUIL': 31,
#  "RUE DE L'HOTEL DE VILLE": 2,
#  'DUGOMMIER': 66,
#  'PIERRE CURIE': 33,
#  'CHEVALERET': 124,
#  'QUATRE CHEMINS - EDOUARD VAILLANT': 2,
#  "MONT D'EST-RER                          ": 4,
#  'EXELMANS': 31,
#  'BOBIGNY-PANTIN (RAYMOND QUENEAU)': 6,
#  'Fosses Rouges': 1,
#  'BONDY': 18,
#  'VILLIERS-LE-BEL-GONESSE-ARNOUVILLE': 246,
#  'VILLENEUVE ST GEORGES RER': 7,
#  'NOTRE-DAME-DE-LORETTE': 30,
#  'PARC DE BERCY': 14,
#  'VILLENEUVE-SAINT-GEORGES': 343,
#  'CHEZY': 1,
#  'PLACE MONGE (JARDIN DES PLANTES)': 40,
#  'PORTE DOREE': 48,
#  'CHEMIN DE BONDY': 1,
#  'GONCOURT (HOPITAL SAINT-LOUIS)': 59,
#  'PORTE DE SAINT-OUEN': 55,
#  'GENERAL LECLERC-VICTOR HUGO             ': 1,
#  'INKERMANN - BINEAU': 2,
#  'PORTE-DE-CLICHY': 7,
#  'PONT-CARDINET': 45,
#  'PIGALLE': 51,
#  'EMERAINVILLE-PONTAULT-COMBAULT': 85,
#  'TERNES': 102,
#  'RUEIL MALMAI': 23,
#  'Eglise': 2,
#  'LIEGE': 23,
#  'SEVRAN-BEAUDOTTES': 133,
#  'CARDINAL LEMOINE - MONGE': 2,
#  'ISSY-VAL DE SEINE': 15,
#  'PORTE DAUPHINE': 146,
#  "GARE DE FIN D'OISE": 23,
#  'CHANTELOUP-LES-VIGNES': 6,
#  'CONFLANS-SAINTE-HONORINE': 30,
#  'MARX DORMOY': 23,
#  'EPINAY-VILLETANEUSE': 77,
#  'SANNOIS': 12,
#  'PORTE DE BAGNOLET': 40,
#  'MAISONS-ALFORT-LES JUILLIOTTES': 17,
#  'Securite Soc': 1,
#  'MONTGERON-CROSNE': 151,
#  'LA DEFENSE                              ': 16,
#  'BERCY': 153,
#  'GARE ROUTIERE QUAI 3': 1,
#  'DUROC': 30,
#  'JUSSIEU': 84,
#  'ASSEMBLEE NATIONALE': 32,
#  'BOUCICAUT': 74,
#  'MONTSOULT-MAFFLIERS': 15,
#  'LOUIS BLANC': 31,
#  'ROUTE DE NEUILLY                        ': 1,
#  'PORTE DE VERSAILLES': 36,
#  'OZOIR-LA-FERRIERE': 40,
#  'CRETEIL-PREFECTURE (HOTEL DE VILLE)': 26,
#  'MENNECY': 22,
#  'ODEON': 16,
#  'BOULOGNE-JEAN JAURES': 23,
#  'PRESLES-COURCELLES': 3,
#  'LES HAUTS BATONS': 5,
#  'PERSAN-BEAUMONT': 15,
#  'CORBEIL-ESSONNES': 51,
#  'VILLEJUIF-PAUL VAILLANT-COUTURIER': 47,
#  'LA VERRIERE': 2,
#  'PARIS Gare d': 3,
#  'GARGES-SARCELLES': 330,
#  'ECOLE MILITAIRE': 56,
#  'NATIONALE': 59,
#  'ALMA-MARCEAU': 31,
#  'KLEBER - BOISSIERE': 6,
#  'PIERRE SERGENT': 1,
#  'PORTE DE CHOISY': 40,
#  '      MARCHE': 1,
#  'GLACIERE': 72,
#  'GALLIENI (PARC DE BAGNOLET)': 56,
#  'PREFECTURE DES HAUTS-DE-SEINE': 1,
#  'OBERKAMPF': 52,
#  'RICHARD LENOIR': 23,
#  'ALSACE': 3,
#  "Gare d'Houilles Carrières sur Seine": 65,
#  "GARE D'ACHERES": 111,
#  'GARE DE MAIS': 27,
#  'HERBLAY': 15,
#  'LE GUICHET': 19,
#  'Gare du Vésinet le Pecq': 55,
#  'GIF-SUR-YVETTE': 12,
#  'PORTE MAILLOT - METRO - RER': 8,
#  'MAURECOURT': 5,
#  'REPUBLIQUE': 229,
#  'COURBEVOIE': 6,
#  'SAVIGNY-SUR-ORGE': 23,
#  'OLOF PALME': 1,
#  'ROUGEMONT-CHANTELOUP': 8,
#  'CHARONNE': 113,
#  'MAISONS-ALFORT - ALFORTVILLE RER': 115,
#  'SEVRAN-LIVRY': 65,
#  "Conflans Fin d'Oise départ": 17,
#  "CHAUSSEE D'ANTIN (LA FAYETTE)": 54,
#  'INVALIDES': 76,
#  'LES HAUTS ROSEAUX': 2,
#  'LA CHAPELLE': 93,
#  "PORTE D'IVRY": 34,
#  'TURBIGO - REPUBLIQUE': 1,
#  'BIRAGUE': 2,
#  'Fose-Survill': 20,
#  'VILLIERS-SUR-MARNE - LE PLESSIS-TREVISE RER': 21,
#  'SALVADOR ALLENDE': 8,
#  'ECOUEN-EZANVILLE': 22,
#  'FAIDHERBE-CHALIGNY': 46,
#  'VAL-DE-FONTENAY RER': 30,
#  'CASTIGLIONE': 1,
#  'MOULIN-GALANT': 11,
#  'GARE MAISONS LAFFITTE': 15,
#  'LES PAVILLONS-SOUS-BOIS': 2,
#  'RUE DU BALLON': 1,
#  'VARENNE': 24,
#  'BONNE NOUVELLE': 93,
#  'SAINT-MICHEL - SAINT-GERMAIN': 3,
#  'JAURES - BARBUSSE': 1,
#  'CHEMIN VERT': 11,
#  'RUEIL MALMAISON GARE RER': 12,
#  'HAUTEVILLE': 1,
#  'LA MUETTE - BOULAINVILLIERS': 2,
#  'AUBERGENVILLE-ELISABETHVILLE': 23,
#  'GRETZ-ARMAINVILLIERS': 20,
#  'BESSANCOURT': 6,
#  'SOLFERINO': 31,
#  'SAINT-LEU-LA-FORET': 11,
#  'Gare SNCF Mantes la Ville': 1,
#  'TAVERNY': 10,
#  'PONT MIRABEAU': 1,
#  'Gare du Blanc Mesnil': 8,
#  'St Germain en Laye RER': 72,
#  'MERIEL': 4,
#  'ERMONT EAUBONNE GARE': 2,
#  'PUTEAUX': 11,
#  'PARC DES EXPOSITIONS': 49,
#  '  ZA Guyards': 1,
#  'BURES-SUR-YVETTE': 11,
#  'GALLIENI': 6,
#  'CAMPO-FORMIO': 12,
#  'MAIRIE DE MONTREUIL': 182,
#  'LAPLACE': 222,
#  'QUAI DE LA GARE': 68,
#  'FALGUIERE': 6,
#  'GAMBETTA': 102,
#  '   GARE NORD': 7,
#  'DOMONT': 30,
#  'MAIRIE DE LIVRY - GARGAN': 1,
#  'ST CHRIST. RER': 16,
#  'COURCELLE-SUR-YVETTE': 14,
#  'FOURNIER': 3,
#  'FREPILLON': 3,
#  'RUE DES BOULETS': 71,
#  'BROCHANT - CARDINET': 7,
#  'JOURDAIN': 59,
#  'LA FRETTE-MONTIGNY': 4,
#  'NOISY-LE-SEC RER': 18,
#  'LA CHENEE': 1,
#  "GARE D'AUSTERLITZ                       ": 2,
#  'LAUMIERE': 19,
#  'CENTRE DE CHATILLON                     ': 1,
#  'Gare SNCF Mantes-la-Jolie': 12,
#  'GARGAN': 8,
#  'DAMMARTIN-JUILLY-SAINT-MARD': 7,
#  'MUSEE DE SEVRES': 2,
#  'THUN-LE-PARADIS': 4,
#  'MAISSE': 4,
#  'Gare Routière Emile Zola': 6,
#  'GROSLAY': 10,
#  'HOCHE': 28,
#  'BUSSY RER': 33,
#  'PETIT-VAUX': 3,
#  'PORTE DE MONTREUIL': 140,
#  'BLANC-MESNIL': 29,
#  'FONTENAY-AUX-ROSES': 46,
#  'RASPAIL': 10,
#  'CESSON': 50,
#  'GARE MASSY PALAISEAU': 39,
#  'COLLEGE AUGUSTIN BOSC': 1,
#  'ERMONT-HALTE': 8,
#  'TREZEL': 5,
#  'MALAKOFF-PLATEAU DE VANVES': 37,
#  'JAVEL': 30,
#  'LA BARRE-ORMESSON': 26,
#  'VINCENNES RER - REPUBLIQUE': 18,
#  'LYCEE DE RUE': 2,
#  'MOULIN VERT                             ': 2,
#  'EGLISE DE PANTIN': 13,
#  'SULLY-MORLAND': 17,
#  'PERE LACHAISE': 59,
#  'BRANCION - VOUILLE': 1,
#  'CENTRE COMME': 2,
#  'PIERRE DEMOURS': 2,
#  'LA BUTTE VERTE': 8,
#  'QUATRE ROUTES': 1,
#  'CORMEILLES-EN-PARISIS': 12,
#  'BRETIGNY': 20,
#  'BERAULT': 57,
#  'SAINT-QUENTIN-EN-YVELINES': 6,
#  'GROS-NOYER-SAINT-PRIX': 17,
#  'DOMONT GARE SNCF': 2,
#  'Bazincourt': 3,
#  'DAUMESNIL - DIDEROT': 4,
#  'RIS-ORANGIS': 29,
#  'MAIRIE DE VILLENEUVE LA GARENNE         ': 3,
#  'SAINT-MICHEL-SUR-ORGE': 10,
#  'MAIRIE DES LILAS': 60,
#  'LOUVRES': 27,
#  'CORVISART': 32,
#  'MONTAIGNE - FRANCOIS 1ER': 1,
#  'LES GOBELINS': 44,
#  'NOISY-CHAMPS RER                        ': 32,
#  'PHILIPPE AUGUSTE': 39,
#  'SAN BENEDETTO': 10,
#  'GARE ROUTIERE DE SARTROUVILLE': 39,
#  'KLEBER': 29,
#  'POINTE RINGA': 2,
#  'LOGNES RER': 6,
#  'GARE CORBEIL': 3,
#  'MAISON BLANCHE': 32,
#  'VIRY-CHATILLON': 14,
#  'GARE ROUTIERE DE HOUILLES': 31,
#  'PLACE DES FETES': 52,
#  'PONT DE NEUILLY-METRO': 9,
#  'ROBINSON': 84,
#  'RICHELIEU-DROUOT': 143,
#  'Hôtel de Ville de Sannois': 1,
#  'PONT DE BIR-HAKEIM': 11,
#  'Lovr-Louvres': 24,
#  'MAISONS-ALFORT-STADE': 28,
#  "Gare d'Emera": 8,
#  "VAL D'EUROPE RER": 51,
#  "TRINITE-D'ESTIENNE D'ORVES": 28,
#  'VILLENEUVE-TRIAGE': 11,
#  'GARE SAINT-LAZARE': 36,
#  'MAIRIE DE MONTREUIL-METRO': 18,
#  'PORTE DE SAINT-CLOUD - MICHEL ANGE': 2,
#  'EPINAY-SUR-ORGE': 8,
#  'VILLEPINTE': 13,
#  'EPONE-MEZIERES': 12,
#  'LES ARDOINES': 7,
#  'BUZENVAL': 58,
#  'ERAGNY SNCF': 3,
#  'JEAN MERMOZ - HENRI BARBUSSE': 2,
#  'CORENTIN-CELTON': 23,
#  'GARE DE CLICHY - LEVALLOIS': 30,
#  'PAIX - VERDUN': 4,
#  'Les Frênes': 1,
#  'PLACE DE BELGIQUE': 11,
#  "PLACE D'ITALIE - MAIRIE DU 13E": 2,
#  'CADET': 65,
#  'PORTE DE CLICHY': 62,
#  'ABLON': 3,
#  'CARNOT': 1,
#  ' Beoi-Mairie': 1,
#  "MAIRIE D'ALFORTVILLE": 13,
#  'SUCY-BONNEUIL RER                       ': 2,
#  "MAIRIE D'IVRY": 23,
#  'ROSNY - BOIS-PERRIER RER - ROSNY 2      ': 7,
#  'Aubo-Grossau': 6,
#  'VAUX-SUR-SEINE': 5,
#  'PONT DE LEVALLOIS-METRO': 4,
#  'SAINT-REMY-LES-CHEVREUSE': 11,
#  'SURVILLIERS-FOSSES': 40,
#  'BOUTIGNY-SUR-ESSONNE': 6,
#  'DAUMESNIL': 115,
#  'ROND POINT PASTEUR': 3,
#  'NANTERRE-VILLE RER': 7,
#  "Gare RER / Val d'Europe - Quai 2": 9,
#  'MICHEL BIZOT': 29,
#  'SAINT-MARCEL': 13,
#  'CHOISY-TOLBIAC                          ': 1,
#  'SIMPLON': 12,
#  'NANTERRE-UNIVERSITE RER                 ': 11,
#  'Marché': 1,
#  'VAVIN': 13,
#  'GARE DE LAGN': 1,
#  'EVRY': 7,
#  'WAGRAM': 58,
#  'SOUFFLOT': 1,
#  'LIEUSAINT  MOISSY GARE RER': 51,
#  'COURONNES': 48,
#  'EGLY': 1,
#  'TERROIRS DE FRANCE': 46,
#  '       LYCEE': 1,
#  'EUROPE': 36,
#  '                      Aubergenville gare': 3,
#  '                        Cergy Préfecture': 1,
#  'LES YVRIS-NOISY-LE-GRAND': 7,
#  'CHATEAU DE VILLEMOMBLE': 1,
#  'JEAN JAURES-HENRI BARBUSSE              ': 1,
#  'RUE DE LA STATION': 9,
#  'NOISY-LE-GRAND RER                      ': 3,
#  "PORTE D'ITALIE-METRO": 5,
#  'SAINT-MICHEL': 8,
#  'PUTEAUX La Défense - Terminal Jules Verne': 5,
#  'LE BRAS-DE-FER': 56,
#  'TORCY RER': 36,
#  'QUAI DE LA RAPEE': 8,
#  'SAINT EXUPERY': 1,
#  'MONTREUIL': 5,
#  'AVENUE DE FRANCE                        ': 12,
#  'ALMA': 1,
#  'CHARENTON-ECOLES': 33,
#  'BILLANCOURT': 48,
#  'EDGAR QUINET': 27,
#  'BIBLIOTHEQUE RUE MANN': 5,
#  'CHAVILLE RIVE DROITE': 3,
#  'SACCO ET VANZETTI': 1,
#  'FONTAINE-MICHALON': 48,
#  'SEVRAN - BEAUDOTTES RER': 1,
#  'GRANDS BOULEVARDS': 4,
#  'FORT DE CHAMPIGNY': 1,
#  'LA COURNEUVE - AUBERVILLIERS RER': 49,
#  'SAINT-PHILIPPE-DU-ROULE': 74,
#  'CORENTIN CARIOU': 45,
#  'LES NOUES': 28,
#  'SAINT-CLOUD': 15,
#  'BOURAY': 7,
#  'LEDRU-ROLLIN': 44,
#  'PORTE DE LA VILLETTE': 27,
#  'PORTE DE COURCELLES': 3,
#  'Mairie': 11,
#  'NANTERRE-PREFECTURE-RER                 ': 1,
#  '      COLMAR': 1,
#  'CHAMPAGNE-SUR-OISE': 2,
#  'LA MUETTE': 36,
#  'DAMREMONT - MARCADET': 3,
#  '                     Chemin des meuniers': 1,
#  'PARMENTIER': 43,
#  'La Roseraie': 1,
#  'SAINT-MAUR': 35,
#  'RENNES': 9,
#  'LA HACQUINIERE': 15,
#  'CHENAY-GAGNY': 12,
#  'CITE DU VIEUX PONT': 2,
#  'LEON BLUM': 1,
#  'PLACE VOLTAIRE                          ': 3,
#  'Bobigny Pablo Picasso': 1,
#  'VIROFLAY RIVE GAUCHE': 2,
#  'GENERAL DE GAULLE': 5,
#  '       EDF 2': 1,
#  'CITE-PALAIS DE JUSTICE                  ': 3,
#  'Gare RER de MitryClaye': 2,
#  'Gare de Lozère': 3,
#  'NOISY-CHAMPS RER - DESCARTES': 3,
#  'PONSCARME': 2,
#  "ORANGIS-BOIS DE L'EPINE": 70,
#  'Evry-Courcouronnes Centre': 4,
#  'PONT DE VITRY': 3,
#  'EGLISE DE BONDY': 4,
#  '      PRAGUE': 1,
#  'SAINT-PLACIDE': 32,
#  'CHATEAU STE BARBE                       ': 1,
#  'VILLENEUVE-LE-ROI': 5,
#  'CHOISY-LE-ROI RER                       ': 3,
#  'BELLOY-SAINT-MARTIN': 3,
#  'GALLIENI-METRO': 8,
#  'LENINE': 2,
#  'BONNIERES': 4,
#  'PEREIRE-LEVALLOIS': 47,
#  'MICHEL-ANGE-MOLITOR': 22,
#  'AVENUE SAINT-REMY': 1,
#  'LOURMEL': 54,
#  'CHARLEBOURG                             ': 11,
#  'GLACIERE - ARAGO': 1,
#  'PLACE DE VERDUN                         ': 1,
#  "MERY-VAL D'OISE": 5,
#  'HOTEL DE VILLE DE FONTENAY-SOUS-BOIS': 1,
#  'CONVENTION - VAUGIRARD': 3,
#  "Conflans Fin d'Oise arrivée": 18,
#  'HOPITAL INTERCOMMUNAL': 3,
#  'MISSOUT': 1,
#  "MAIRIE D'IVRY-METRO": 6,
#  "VAL-D'ARGENTEUIL": 27,
#  'HOPITAL DU KREMLIN-BICETRE': 2,
#  "GARE ROUTIERE D'ARGENTEUIL": 14,
#  'CHARTRES': 2,
#  'ALLEE DE LA TOUR RENDEZ-VOUS': 1,
#  'NEUILLY-PLAISANCE RER': 12,
#  'LARDY': 2,
#  'VIARMES': 2,
#  'BOULEREAUX C': 1,
#  'Manoir': 1,
#  'PARIS G LYON': 1,
#  'CONSEIL GENERAL': 1,
#  'HAUSSMANN - MOGADOR': 2,
#  'PARC-DE-SCEAUX': 32,
#  'CHARLES HELLER                          ': 2,
#  'CARREFOUR DE LA RESISTANCE              ': 1,
#  'CARREFOUR DE CHATEAUDUN': 5,
#  'PONT DE LA GRANDE JATTE': 4,
#  'Centre Commercial ulis 2': 2,
#  "PONT D'AUSTERLITZ - QUAI DE LA RAPEE": 5,
#  'DANIELLE CASANOVA                       ': 2,
#  'NOISY-LE-SEC RER                        ': 1,
#  'LA NORVILLE-SAINT-GERMAIN-LES-ARPAJON': 3,
#  'BUTTES-CHAUMONT': 5,
#  'REAUMUR-SEBASTOPOL': 16,
#  'SAINT-AMBROISE': 85,
#  'Gare RER - Quai de dépose': 22,
#  'VSG GareMairie': 7,
#  'PONT DE SEVRES': 26,
#  'MANTES-STATION': 23,
#  'NEUILLY-PLAISANCE RER.': 3,
#  'RAYMOND JACLARD': 7,
#  'CAMBRONNE - VAUGIRARD': 1,
#  'LES BOURGUIGNONS': 1,
#  'Roissy RER': 11,
#  'GARE DE BONDY RER': 2,
#  'Les Ecuyers': 2,
#  'JULES GUESDE                            ': 3,
#  'SURESNES-MONT VALERIEN': 6,
#  'MARLY-LE-ROI': 1,
#  'POMPIDOU                                ': 1,
#  'ESPLANADE C.D.G                         ': 8,
#  'LE KREMLIN-BICETRE-METRO': 9,
#  'MAIRIE DES LILAS - METRO': 6,
#  '      ZURICH': 2,
#  'VAUCELLES': 4,
#  'Roissypôle RER': 8,
#  'LES GRESILLONS': 2,
#  'FRATERNELLE': 4,
#  'LIMAY': 5,
#  'PALAIS ROYAL - COMEDIE FRANCAISE': 4,
#  'Orée de Sénart': 1,
#  'PIERRE DE GEYTER                        ': 1,
#  'M. Galant RE': 6,
#  'GARGENVILLE': 2,
#  'Sucy RER': 53,
#  'CHARLES DE GAULLE - ETOILE - WAGRAM': 3,
#  'La Villeneuve': 1,
#  'PASSY - BOULAINVILLIERS': 1,
#  'KLEBER - PAUL VALERY': 3,
#  'LOZERE': 19,
#  'PISCINE': 1,
#  'Pôle Lafarge': 2,
#  'LYCEE HENRI SELLIER': 4,
#  "Gare d'Igny": 2,
#  'VILLENNES-SUR-SEINE': 4,
#  'SUZANNE LENGLEN': 15,
#  'HAUSSMANN - MIROMESNIL': 7,
#  'BOTZARIS': 10,
#  ' DEFENSE TJV': 16,
#  'LES COTEAUX': 3,
#  'Ml Juin': 1,
#  'DELAUNAY-BELLEVILLE                     ': 1,
#  ' POLY. LABO.': 1,
#  'VAL DE FONTENAY RER': 14,
#  'DENFERT-ROCHEREAU - DAGUERRE': 1,
#  'BELLINI': 2,
#  'LES MOULINEAUX                          ': 1,
#  'GARE -PANTIN': 1,
#  "CRETEIL-L'ECHAT (HOPITAL MONDOR)": 25,
#  'VERSAILLES CHATEAU': 4,
#  'MAURICE BARRES': 2,
#  'Pierre Curie': 2,
#  'MEDIATHEQUE DU SEGRAIS': 1,
#  'RAPP - LA BOURDONNAIS': 1,
#  'BRETIGNY GAR': 1,
#  'PAUL DOUMER': 3,
#  'JEAN MACE                               ': 3,
#  'PIERRELAYE': 3,
#  'VICTOR BASCH                            ': 2,
#  'SCEAUX': 37,
#  'RUE DE SEINE': 4,
#  "Gare d'Orsay Ville": 2,
#  'Gare RER Poissy': 2,
#  'GARE DES MARCHANDISES': 11,
#  'Le Cep': 1,
#  'MARX DORMOY-CARNOT': 1,
#  "Gare RER / Val d'Europe - Quai de dépose": 3,
#  'EGLISE DE SAINT-MANDE': 3,
#  'ENGHIEN MERMOZ GARE': 9,
#  'LE CROULT': 1,
#  'NOGENT-LE-PERREUX RER': 19,
#  'ACHERES-GRAND-CORMIER': 2,
#  'PLACE DU 18 JUIN 1940': 2,
#  'Gosa-Résiden': 2,
#  'PORT AUX LIONS': 5,
#  'VOLTAIRE (LEON BLUM)': 111,
#  'QUATRE ROUTES                           ': 3,
#  'Marly le Roi Gare': 1,
#  'SONNETTES': 1,
#  'OPERA - 4 SEPTEMBRE': 8,
#  'VIGNES BLANCHES': 2,
#  'PORTE DAUPHINE - MARECHAL DE LATTRE DE TASSIGNY': 6,
#  'Gare de Montigny Beauchamp': 2,
#  'LEGENDRE': 5,
#  '         GSQ': 3,
#  'BASTILLE - FAUBOURG SAINT-ANTOINE': 2,
#  'TERNES - MAC MAHON': 4,
#  'VALMY - GAMBETTA - STADE': 1,
#  'FILLES DU CALVAIRE': 18,
#  'LES BEAUX VENTS': 1,
#  'MAIRIE DE DRANCY': 1,
#  "L'ISLE-ADAM-PARMAIN": 2,
#  'Gare Ardoine': 1,
#  "SAINT-OUEN-L'AUMONE": 2,
#  'La Celle St Cloud - Gare': 1,
#  'ANCIENNE MAIRIE                         ': 1,
#  'GENERAL KOENIG - PALAIS DES CONGRES': 2,
#  'DIDOT': 2,
#  "MUSEE D'ORSAY": 4,
#  'MIRABEAU': 6,
#  'AVENUE FOCH': 9,
#  'MAIRIE NEUVILLE': 4,
#  "L'ABBAYE": 4,
#  'LUZARCHES': 5,
#  '    GARE RER': 8,
#  'CHILLY-MAZARIN': 1,
#  'PONT DE NEUILLY': 9,
#  'BREGUET - SABIN': 1,
#  'PORTE MAILLOT - PALAIS DES CONGRES': 1,
#  'CLAUDE TILLIER': 1,
#  'Gare de Bondy': 1,
#  'PANTIN - RAYMOND QUENEAU': 1,
#  'REPUBLIQUE-F. MITTERRAND                ': 2,
#  'COLLEGE JACQUELINE DE ROMILLY': 1,
#  'SEGUR': 5,
#  'JUSSIEU                                 ': 1,
#  'PROVENCE - FAUBOURG MONTMARTRE': 1,
#  'Gare SNCF Vernouillet-Verneuil': 26,
#  'RICHELIEU - DROUOT - MAIRIE DU 9E': 1,
#  'MONTGALLET': 24,
#  'NATION - PLACE DES ANTILLES': 8,
#  'CHAMPIGNY - SAINT-MAUR RER': 2,
#  'THOMAS MANN': 2,
#  'TRINITE': 5,
#  'HOTEL DE VILLE - MAISON DE LA CULTURE': 2,
#  'SOLJENITSYNE': 2,
#  'LA PLAINE': 8,
#  'ARMAND CARREL - MAIRIE DU 19E': 2,
#  'Pasteur': 4,
#  'BOURGAIN - GENERAL GALLIENI': 1,
#  'Les Clairières': 2,
#  'Gretz SNCF': 2,
#  'LAGNY-THORIGNY': 5,
#  'HOCHE-METRO': 3,
#  'JACQUELINE AURIOL                       ': 4,
#  'Anizan Cavillon  Mairie': 5,
#  'MONTROSIER - PARMENTIER': 1,
#  'LA FERTE-ALAIS': 4,
#  'COMBS LA VILLE GARE RER': 45,
#  'OBERKAMPF - FILLES DU CALVAIRE': 3,
#  'ACHTARAK                                ': 5,
#  'CHELLES-GOURNAY': 10,
#  'Gare de Sartrouville': 29,
#  'VERSAILLES RIVE DROITE': 2,
#  'CHATEAU-LANDON': 21,
#  'Gare de Sannois': 2,
#  'Clos du Roy': 1,
#  'VILLABE': 3,
#  'ABBE GEORGES HENOCQUE                   ': 1,
#  'ROSE DES VENTS': 1,
#  'MAIRIE DE SAINT-MANDE': 1,
#  'VAUCRESSON': 2,
#  'GARE ROUTIERE QUAI 1': 1,
#  'PLAISANCE - HOPITAL SAINT-JOSEPH': 4,
#  'Gare Routière Bonnières': 1,
#  'Corneille': 1,
#  'SNCF': 15,
#  'PRES DES ROCHES': 1,
#  'PARC MARTIN LUTHER KING': 6,
#  'RER Champigny': 12,
#  "Gare d'Epinay": 1,
#  'PAUL BERT': 3,
#  'LA PEROUSE                              ': 2,
#  "MAIRIE D'ISSY-METRO": 5,
#  'VILLIERS SUR MARNE-LE PLESSIS TREVISE-RER': 45,
#  'Prés St-Mart': 1,
#  'Trou Grillon 6': 1,
#  'Yerres GARE': 75,
#  'Grand Park': 1,
#  'EGLISE DE VILLIERS-SUR-MARNE': 1,
#  'LES QUATRE PAVES': 1,
#  'CESSON GARE RER': 20,
#  'DIJON - LACHAMBEAUDIE': 8,
#  'GARE DE LYON - DIDEROT': 59,
#  'Antony RER': 18,
#  'GEORGES MILLANDY                        ': 1,
#  'MLV GARE ROU': 3,
#  'LE MORILLON': 2,
#  'RUEIL-MALMAISON RER                     ': 2,
#  'Château': 1,
#  'COLOMBES': 24,
#  'LIBERATION': 7,
#  '    RER Sucy': 9,
#  'Palaiseau Ville': 8,
#  'MAIRIE DE SAINT-OUEN - METRO': 2,
#  'Clos de Massy': 1,
#  'LE BONTEMPS': 2,
#  'ANCIENNE MAIRIE DE LE_BLANC-MESNIL': 10,
#  'RIVOLI - PONT NEUF': 2,
#  'GARE DE LEST': 1,
#  'JASMIN': 19,
#  'COURS DE VINCENNES': 7,
#  'GARE SAINT LAZARE                       ': 5,
#  'MOISSY CENTRE': 2,
#  'THEATRE JOUY': 3,
#  'JACQUES BONSERGENT': 13,
#  'SAULE DE LA CHASSE': 1,
#  'VICTOR BASCH': 1,
#  'FONTAINEBLEAU-AVON': 3,
#  'CHATEAU DE VINCENNES-METRO              ': 7,
#  'Place Verte': 1,
#  'Gare de Massy Palaiseau B': 27,
#  'Gare de Saint Leu la Foret': 1,
#  'Aubrac': 1,
#  'LA BOISSIERE': 4,
#  'BROSSOLETTE GARE DE BRETIGNY': 1,
#  'HENRI IV': 1,
#  'SOUS-PREFECTURE - JULES FERRY': 3,
#  'MAIRIE ST OUEN': 1,
#  'LE FRESNE': 2,
#  'MAISONS-ALFORT - ALFORTVILLE RER.': 12,
#  'Gare du Vésinet Centre': 9,
#  'CHARONNE-KELLER': 2,
#  'TRIEL-SUR-SEINE': 4,
#  'GRANGE AU BOIS': 3,
#  '   Torcy RER': 7,
#  'PONT DE TOLBIAC': 2,
#  'Asoi-Baillon': 3,
#  'MAIRIE DE VILLIERS-SUR-MARNE            ': 2,
#  "VAL D'EUROPE": 9,
#  'Terminal Jules Verne': 6,
#  'Temps des Cerises-Snecma': 5,
#  'Gare de Palaiseau Villebon': 4,
#  'RUE DES POMMIERS': 1,
#  'Montgeron GARE': 83,
#  'GAMBETTA - MAIRIE DU 20E': 6,
#  'LA CHALLE': 3,
#  'BASTILLE - RUE SAINT-ANTOINE': 4,
#  'CROIX BLANCHE': 1,
#  'RUE DU POINT DU JOUR': 3,
#  'SOUVENIR FRANCAIS': 1,
#  "SAINT-OUEN-L'AUMONE-LIESSE": 4,
#  'EDOUARD VAILLANT': 4,
#  'GARCHES-MARNES-LA-COQUETTE': 1,
#  'BUNO-GIRONVILLE': 1,
#  'GARE MONTPARNASSE': 1,
#  'ERAGNY-NEUVILLE': 4,
#  'RER - RASPAIL': 2,
#  'Robert Capa': 1,
#  'LA PLAINE - STADE DE FRANCE RER': 9,
#  'PORTE DE VINCENNES                      ': 54,
#  'Gosa-Ecoleje': 1,
#  'GARE SAINT-LAZARE - BUDAPEST': 12,
#  'Gare de Saint Brice': 4,
#  'DRANCY RER': 46,
#  'CIMETIERE PARISIEN DE THIAIS': 1,
#  'ISSY': 3,
#  'ETAMPES': 7,
#  'Gare de Triel': 1,
#  "LE VAL-D'OR": 2,
#  'MAURICE BERTEAUX                        ': 2,
#  'PORT ROYAL-SAINT JACQUES                ': 2,
#  'Place du 14 Juillet': 2,
#  'Place de la Libération': 1,
#  'POSTE ZI BUSSY': 2,
#  'Fose-Hautegr': 2,
#  'CERGY LE HT RER': 34,
#  'ORLY OUEST - ARRIVEES DES VOLS': 1,
#  'GENERAL SCHRAMM': 16,
#  'PONT CARDINET': 11,
#  'PANTIN RER - MAIRIE.': 8,
#  'ARISTIDE BRIAND-LE PLANT                ': 1,
#  ...}

# %%
x = [a[0] for a in O_counts]
y = [a[1] for a in O_counts]

# %%
plt.figure(figsize=(15,5))
plt.bar(np.arange(len(x)) , y)
plt.xticks(np.arange(len(x)), x, rotation = 90)
plt.xlabel('arrets')
plt.ylabel('counts')
plt.show()

# %%
D_counts = get_counts(test_RER['D'])

# %%
D_counts
# Out:
# {'NATION': 2388,
#  nan: 699,
#  'MASSY-PALAISEAU': 157,
#  'SAVIGNY-LE-TEMPLE-NANDY': 90,
#  'BERAULT-METRO': 4,
#  'PONT DE NEUILLY (AVENUE DE MADRID)': 98,
#  'LA DEFENSE-GRANDE ARCHE': 3986,
#  'JUZIERS': 3,
#  'BALLANCOURT': 8,
#  'NOGENT-SUR-MARNE': 295,
#  'SAINT-GEORGES - CHATEAUDUN': 5,
#  'SAINT-LAZARE': 585,
#  'CONVENTION': 34,
#  'POISSY': 357,
#  'GARE DE LYON': 3836,
#  'AUBER': 2939,
#  'CHATOU-CROISSY': 262,
#  'MAULE': 1,
#  'HOUILLES-CARRIERES-SUR-SEINE': 444,
#  'ROISSY-EN-BRIE': 31,
#  'PICPUS': 28,
#  'Lovr-Bruxell': 1,
#  'OLYMPIADES': 203,
#  'SAINT-GERMAIN-DES-PRES': 12,
#  'CHARLES DE GAULLE ETOILE': 2534,
#  'GRANDS BOULEVARDS (RUE MONTMARTRE)': 72,
#  'MELUN': 14,
#  "Gare d'Aulnay sous Bois": 18,
#  'NANTERRE-PREFECTURE': 689,
#  'LE VESINET-LE PECQ': 217,
#  'STADE LEO LAGRANGE': 1,
#  'CERGY LE HAUT': 333,
#  'SARTROUVILLE': 460,
#  'CITE UNIVERSITAIRE': 143,
#  'LA PLAINE-STADE DE FRANCE': 162,
#  'LE PELETIER': 55,
#  'CHATELET-LES HALLES': 2218,
#  'PANTIN': 33,
#  'BIBLIOTHEQUE FRANCOIS MITTERRAND': 587,
#  'COMBS-LA-VILLE-QUINCY': 79,
#  'NANTERRE-UNIVERSITE': 435,
#  'LES BOULLEREAUX-CHAMPIGNY': 29,
#  'PORTE DES LILAS': 45,
#  'NEUILLY-PLAISANCE': 534,
#  'PORTE MAILLOT': 145,
#  'CAMBRONNE': 44,
#  'RUEIL-MALMAISON': 743,
#  'GARE DU NORD': 590,
#  'JOINVILLE-LE-PONT': 398,
#  'Aérospatiale': 1,
#  'LA VARENNE-CHENNEVIERES': 210,
#  "CHAMP DE COURSES D'ENGHIEN": 6,
#  'DUPLEIX': 72,
#  "VAL-D'EUROPE": 413,
#  "CONFLANS-FIN-D'OISE": 146,
#  'BOISSIERE': 41,
#  'BOURG-LA-REINE': 146,
#  'TORCY': 403,
#  'MADELEINE': 170,
#  'CAMELIAS': 5,
#  'VINCENNES': 878,
#  'VAL-DE-FONTENAY': 865,
#  "PORTE D'ORLEANS": 14,
#  'CHESSY - MARNE-LA-VALLEE': 337,
#  'JEAN JAURES': 2,
#  'PONT DE LEVALLOIS-BECON': 81,
#  'LE MEE': 27,
#  'AUSTERLITZ': 32,
#  'BOIS PERRIER RER-ROSNY 2                ': 1,
#  'GENTILLY': 90,
#  'STADE DE FRANCE-SAINT-DENIS': 258,
#  'CHATEAU DE VINCENNES': 26,
#  'DENFERT-ROCHEREAU': 148,
#  'COMMERCE': 33,
#  'SAINT-GERMAIN-EN-LAYE': 474,
#  'PROGRES - ARNAUD CARREL': 5,
#  'ESSONNES-ROBINSON': 4,
#  'LOGNES': 199,
#  'CHAMPIGNY': 366,
#  'PORT ROYAL': 120,
#  "GARE D'ACHERES": 69,
#  'PONTOISE': 7,
#  'CHAMPS-ELYSEES-CLEMENCEAU': 53,
#  'MAIRIE DE CLICHY': 53,
#  'BOIS-COLOMBES': 25,
#  'BOBIGNY-PABLO PICASSO': 10,
#  'SEVRES-BABYLONE': 23,
#  'NOGENT-LE-PERREUX RER                   ': 5,
#  'AVENUE DU CHATEAU': 4,
#  'LE VESINET-CENTRE': 136,
#  'SAINTE-GENEVIEVE': 1,
#  'LA TOUR MAUBOURG': 24,
#  'ARGENTINE': 48,
#  'FONTENAY-SOUS-BOIS': 279,
#  "PORTE D'ITALIE": 12,
#  'LES VALLEES': 43,
#  'BRY-SUR-MARNE': 248,
#  'BROCHANT': 20,
#  'SAINT-FRANCOIS-XAVIER': 15,
#  'LES SABLONS': 2,
#  'BAGNEUX': 78,
#  'AEROPORT CHARLES DE GAULLE 1': 42,
#  'BOISSY-SAINT-LEGER': 293,
#  'NOISY-CHAMPS': 628,
#  'LA GARENNE-COLOMBES': 40,
#  'SAINT-DENIS-PORTE DE PARIS': 5,
#  'M. Galant RE': 5,
#  'BASTILLE': 149,
#  'BUSSY-SAINT-GEORGES': 345,
#  'CERGY-PREFECTURE': 604,
#  'ESPLANADE DE LA DEFENSE': 144,
#  'LUXEMBOURG': 258,
#  'Gare Sud départ': 21,
#  'SARCELLES-SAINT-BRICE': 31,
#  'OPERA': 201,
#  'RUE DE LA POMPE (AVENUE GEORGES MANDEL)': 31,
#  'ROBESPIERRE': 83,
#  'MONTPARNASSE': 123,
#  'BASILIQUE DE SAINT-DENIS': 13,
#  'REUILLY-DIDEROT': 133,
#  'JULES QUENTIN': 1,
#  'AULNAY-SOUS-BOIS': 110,
#  'TUILERIES': 32,
#  'ACHERES-VILLE': 67,
#  "NOISY-LE-GRAND-MONT D'EST": 861,
#  'GARIBALDI': 25,
#  'MAISONS-LAFFITTE': 272,
#  'CHOISY-LE-ROI': 5,
#  "LES SABLONS (JARDIN D'ACCLIMATATION)": 112,
#  'COLONEL FABIEN': 42,
#  'GRIGNY-CENTRE': 78,
#  'VITRY-SUR-SEINE': 8,
#  'RANELAGH': 15,
#  'AEROPORT CHARLES DE GAULLE 2-TGV': 31,
#  'AUBERVILLIERS-PANTIN (QUATRE CHEMINS)': 28,
#  'NOTRE-DAME-DES-CHAMPS': 8,
#  'PERE LACHAISE': 38,
#  'NOISY-LE-SEC': 45,
#  'SENTIER': 22,
#  'MONCEAU': 40,
#  'EVRY-COURCOURONNES': 143,
#  'LE PARC-DE-SAINT-MAUR': 243,
#  'SAINT-DENIS': 221,
#  'SAINT-DENIS-UNIVERSITE': 30,
#  'HAUSSMANN-SAINT-LAZARE': 320,
#  'ARTS ET METIERS': 29,
#  'BEL-AIR': 58,
#  'NANTERRE-VILLE': 375,
#  'NOISIEL': 276,
#  'TOLBIAC': 16,
#  'MEULAN-HARDRICOURT': 6,
#  'JULES JOFFRIN': 14,
#  'ROSNY-SOUS-BOIS': 66,
#  'ANTONY': 149,
#  'VILLEPARISIS-MITRY-LE-NEUF': 37,
#  'PASTEUR': 69,
#  'CHATELET': 123,
#  'PYRAMIDES': 156,
#  'Préfecture Gare': 1,
#  'SAINT-MAUR-CRETEIL': 331,
#  'YERRES': 80,
#  'LA MOTTE-PICQUET-GRENELLE': 68,
#  'MICHEL-ANGE-AUTEUIL': 17,
#  'BIR-HAKEIM (GRENELLE)': 61,
#  'BALZAC': 5,
#  'OURCQ': 17,
#  'CERGY-SAINT-CHRISTOPHE': 271,
#  'MONTIGNY-BEAUCHAMP': 10,
#  'PLACE DE CLICHY': 66,
#  'BARBES-ROCHECHOUART': 38,
#  'PERNETY': 14,
#  'HOTEL DE VILLE': 124,
#  'PIERREFITTE-STAINS': 105,
#  'POISSONNIERE': 42,
#  'VILLIERS': 73,
#  'LES GRESILLONS RER': 1,
#  'MAISONS-ALFORT - ALFORTVILLE RER': 68,
#  'SAINT-MANDE-TOURELLE': 133,
#  'MAIRIE DE SAINT-OUEN': 21,
#  'LES COQUETIERS': 1,
#  'FRANCONVILLE-LE-PLESSIS-BOUCHARD': 25,
#  'VILLEJUIF-LOUIS ARAGON': 49,
#  'TROCADERO': 74,
#  'VICTOR HUGO': 91,
#  'SAINT-JACQUES': 8,
#  'CONDORCET - MAIRIE-RER': 1,
#  'QUATRE SEPTEMBRE': 45,
#  'CRIMEE': 40,
#  'GOUSSAINVILLE': 61,
#  'IENA': 16,
#  'SAINT-PAUL (LE MARAIS)': 95,
#  'BOIS PERRIER-RER-ROSNY 2                ': 6,
#  'ECOLE DES MARADAS': 1,
#  'TOURNAN': 13,
#  'CHATILLON-MONTROUGE': 27,
#  'SUCY-BONNEUIL': 206,
#  'PLAISANCE': 26,
#  "GARE DE L'EST": 61,
#  'NEUVILLE UNIVERSITE': 86,
#  'SAINT-AUGUSTIN': 64,
#  'BECON-LES-BRUYERES': 53,
#  'HOTEL DE VILLE DE BOIS-COLOMBES': 1,
#  'PORTE DE PANTIN': 7,
#  'PORTE DE VINCENNES': 98,
#  'ERMONT-EAUBONNE': 39,
#  'PALAISEAU-VILLEBON': 18,
#  'MAISONS-ALFORT-ALFORTVILLE': 145,
#  'PALAISEAU': 12,
#  "Gare d'Orsay Ville - Arrivée": 15,
#  'VILLEJUIF-LEO LAGRANGE': 32,
#  'GUY MOQUET': 29,
#  'LIEUSAINT-MOISSY': 95,
#  'ARGENTEUIL': 34,
#  'LES AGNETTES-ASNIERES-GENNEVILLIERS': 10,
#  'LA COURNEUVE-AUBERVILLIERS': 65,
#  'DRANCY': 48,
#  "FORT D'AUBERVILLIERS": 11,
#  'Gare RER Chatou Croissy': 25,
#  'LAMARCK-CAULAINCOURT': 19,
#  'VILLIERS-SUR-MARNE-PLESSIS-TREVISE': 60,
#  'STALINGRAD': 35,
#  'VERT-GALANT': 62,
#  'ROME': 28,
#  'PASSY': 58,
#  'ANATOLE FRANCE': 59,
#  'FRANKLIN-D.ROOSEVELT': 168,
#  'GARE DE MAIS': 18,
#  'BOURG LA REINE-RER                      ': 2,
#  'CLICHY-LEVALLOIS': 58,
#  'LOUVRE-RIVOLI': 12,
#  'PORTE DE LA CHAPELLE': 6,
#  'ARCUEIL-CACHAN': 89,
#  'SAINT-MICHEL NOTRE DAME': 130,
#  'ALESIA': 6,
#  'SAINT-GEORGES': 13,
#  "MAIRIE D'ISSY": 16,
#  'GAGNY': 11,
#  'GARE DE COLOMBES': 2,
#  'ROSNY-BOIS-PERRIER': 40,
#  'RUEIL-MALMAISON RER': 4,
#  'BLANCHE': 17,
#  'NEUILLY-PLAISANCE RER': 9,
#  'LES HALLES': 75,
#  'CONCORDE': 55,
#  'ASNIERES': 22,
#  'MITRY-CLAYE': 17,
#  'VIGNEUX-SUR-SEINE': 102,
#  'GARE DU GUIC': 3,
#  'LA COURNEUVE - AUBERVILLIERS RER': 39,
#  'ABBESSES': 8,
#  'VINCENNES RER                           ': 2,
#  'BRUNOY': 122,
#  'BOUFFEMONT-MOISSELLES': 8,
#  'LE VERT-DE-MAISONS': 91,
#  'Ursulines': 1,
#  'CENSIER-DAUBENTON': 65,
#  'ARMORIQUE-MUSEE POSTAL                  ': 1,
#  'MARCHE                                  ': 1,
#  'CHAVILLE-VELIZY': 1,
#  'NOGENT-LE-PERREUX': 40,
#  'ENGHIEN-LES-BAINS': 30,
#  'Gare de Sevran Livry': 4,
#  'CHARDON-LAGACHE': 1,
#  "CHATEAU D'EAU": 7,
#  'PYRENEES': 31,
#  'COURCELLES': 69,
#  'ECOLE VETERINAIRE DE MAISONS-ALFORT': 25,
#  'BREGUET-SABIN': 17,
#  'ANVERS': 26,
#  'MANTES-LA-JOLIE': 6,
#  'MALAKOFF-RUE ETIENNE DOLET': 16,
#  'GEORGE V': 70,
#  'PORTE DE VANVES': 20,
#  'MENIL': 1,
#  'NEUVILLE RER': 40,
#  'MAGENTA': 39,
#  'ROND-POINT DES PYRAMIDES': 1,
#  'BERCY': 91,
#  'MAIRIE DE COLOMBES': 2,
#  'SAINT GERMAIN-ODEON                     ': 1,
#  'TELEGRAPHE': 34,
#  "PORTE D'ORLEANS-METRO": 2,
#  'SOUFFLOT': 2,
#  'COUR SAINT-EMILION': 180,
#  'PONT-NEUF (LA MONNAIE)': 2,
#  'LES MUREAUX': 42,
#  'CRETEIL-UNIVERSITE': 16,
#  'LE BOURGET': 96,
#  'LES BACONNETS': 60,
#  'Montereau SNCF': 1,
#  'LA CROIX-DE-BERNY-FRESNES': 61,
#  'STRASBOURG-SAINT-DENIS': 33,
#  'LE RAINCY-VILLEMOMBLE-MONTFERMEIL': 18,
#  'J. Jaurès': 1,
#  'LA DEFENSE                              ': 9,
#  'MIROMESNIL': 81,
#  'BELLEVILLE': 99,
#  'GARE DE MAISONS-LAFFITTE-RER': 6,
#  'ORSAY-VILLE': 24,
#  'MARCEL SEMBAT': 53,
#  'PANTIN RER - MAIRIE.': 6,
#  'BOUSSY-SAINT-ANTOINE': 74,
#  'HAVRE-CAUMARTIN': 39,
#  'GABRIEL PERI-ASNIERES-GENNEVILLIERS': 27,
#  'ALEXANDRE DUMAS': 61,
#  'Commissariat': 4,
#  'PALAIS ROYAL-MUSEE DU LOUVRE': 55,
#  'SEVRES-LECOURBE': 32,
#  'LA COURNEUVE 8 MAI 1945': 17,
#  'JEAN-PIERRE TIMBAUD': 2,
#  'ROND-POINT DES CHAMPS-ELYSEES': 5,
#  'VILLIERS-SUR-MARNE-LE PLESSIS-TREVISE RER': 3,
#  'FELIX FAURE': 30,
#  'Roissypôle RER': 9,
#  'Médiathèque': 1,
#  'Lycée Alain': 1,
#  'MARAICHERS': 63,
#  'VERDUN': 3,
#  'Gare RER Cergy Préfecture': 3,
#  'BALARD': 62,
#  'IVRY-SUR-SEINE': 12,
#  'RUE DU BAC': 29,
#  'Gare de Villepinte': 18,
#  'LA FOURCHE': 18,
#  'GAITE': 12,
#  'LIBERTE': 22,
#  'LOUISE MICHEL': 63,
#  '              Neuville-sur-Oise Gare RER': 1,
#  'LES COURTILLES': 16,
#  'CARREFOUR PLEYEL': 21,
#  'MENILMONTANT': 40,
#  'MARCADET-POISSONNIERS': 13,
#  'Gare du Vésinet le Pecq': 35,
#  'PORTE DE CHAMPERRET': 33,
#  'CHARLES MICHELS': 28,
#  'MALESHERBES': 36,
#  'RD 7 - PONT DE NEUILLY': 1,
#  "PLACE D'ITALIE": 70,
#  'LE GRILLON': 3,
#  'VOLONTAIRES': 6,
#  'SAINT-SEBASTIEN FROISSART': 15,
#  'BERNAU DOLET': 1,
#  'GARE DE SAINT GERMAIN EN LAYE': 8,
#  'JUVISY': 75,
#  'LE KREMLIN-BICETRE': 42,
#  'JAURES': 26,
#  'ROISSYPOLE': 1,
#  'MASSY-VERRIERES': 9,
#  'BOURSE': 63,
#  'LA DEFENSE-RER                          ': 5,
#  'CERNAY': 7,
#  'PORTE DE SAINT-CLOUD': 32,
#  'GARE DE LA C': 5,
#  'VAUGIRARD (ADOLPHE CHERIOU)': 33,
#  'NORMANDIE': 1,
#  'DEUIL-MONTMAGNY': 10,
#  'CROIX DE CHAVAUX (JACQUES DUCLOS)': 71,
#  'VERNOUILLET-VERNEUIL': 18,
#  "RUE DE L'HOTEL DE VILLE": 2,
#  'DUGOMMIER': 30,
#  'TORCY RER': 25,
#  'PIERRE CURIE': 18,
#  'CHEVALERET': 78,
#  'QUATRE CHEMINS - EDOUARD VAILLANT': 1,
#  "MONT D'EST-RER                          ": 4,
#  'EXELMANS': 15,
#  'BOBIGNY-PANTIN (RAYMOND QUENEAU)': 3,
#  'Fosses Rouges': 1,
#  'BONDY': 13,
#  'VILLIERS-LE-BEL-GONESSE-ARNOUVILLE': 131,
#  'VILLENEUVE ST GEORGES RER': 6,
#  "Gare d'Houilles Carrières sur Seine": 42,
#  'VILLENEUVE-SAINT-GEORGES': 193,
#  'CORBEIL-ESSONNES': 28,
#  'HERBLAY': 10,
#  'LE GUICHET': 15,
#  'GIF-SUR-YVETTE': 8,
#  'PORTE MAILLOT - METRO - RER': 6,
#  'MAURECOURT': 3,
#  'PIGALLE': 27,
#  'REPUBLIQUE': 132,
#  'PORTE DE SAINT-OUEN': 36,
#  'COURBEVOIE': 5,
#  'SAVIGNY-SUR-ORGE': 18,
#  'OLOF PALME': 1,
#  'ROUGEMONT-CHANTELOUP': 6,
#  'CHARONNE': 66,
#  'SEVRAN-LIVRY': 35,
#  "Conflans Fin d'Oise départ": 12,
#  "CHAUSSEE D'ANTIN (LA FAYETTE)": 38,
#  'INVALIDES': 41,
#  'LES HAUTS ROSEAUX': 2,
#  'PORTE DAUPHINE': 84,
#  'RER DE CHESSY': 3,
#  'LA CHAPELLE': 45,
#  "PORTE D'IVRY": 19,
#  'TURBIGO - REPUBLIQUE': 1,
#  'MAISONS-ALFORT-LES JUILLIOTTES': 10,
#  'BIRAGUE': 2,
#  'EMERAINVILLE-PONTAULT-COMBAULT': 47,
#  'OZOIR-LA-FERRIERE': 21,
#  'Fose-Survill': 12,
#  'VILLIERS-SUR-MARNE - LE PLESSIS-TREVISE RER': 11,
#  'SALVADOR ALLENDE': 5,
#  'ECOUEN-EZANVILLE': 9,
#  'FAIDHERBE-CHALIGNY': 31,
#  'VAL-DE-FONTENAY RER': 17,
#  'CASTIGLIONE': 1,
#  'ODEON': 8,
#  'MOULIN-GALANT': 8,
#  'GARE MAISONS LAFFITTE': 8,
#  'LES PAVILLONS-SOUS-BOIS': 2,
#  'RUE DU BALLON': 1,
#  'DUROC': 15,
#  'VARENNE': 14,
#  'BONNE NOUVELLE': 52,
#  'SEVRAN-BEAUDOTTES': 82,
#  'SAINT-MICHEL - SAINT-GERMAIN': 2,
#  'JAURES - BARBUSSE': 1,
#  'CHEMIN VERT': 10,
#  'MONTGERON-CROSNE': 89,
#  'RUEIL MALMAISON GARE RER': 10,
#  'GALLIENI (PARC DE BAGNOLET)': 35,
#  'HAUTEVILLE': 1,
#  'LA MUETTE - BOULAINVILLIERS': 1,
#  'AUBERGENVILLE-ELISABETHVILLE': 13,
#  'PONT-CARDINET': 19,
#  'GRETZ-ARMAINVILLIERS': 14,
#  'BESSANCOURT': 4,
#  'SOLFERINO': 20,
#  'SAINT-LEU-LA-FORET': 8,
#  'Gare SNCF Mantes la Ville': 1,
#  'TAVERNY': 4,
#  'PONT MIRABEAU': 1,
#  'Gare du Blanc Mesnil': 6,
#  'St Germain en Laye RER': 41,
#  'MERIEL': 3,
#  'ERMONT EAUBONNE GARE': 2,
#  'DOCTEUR CALMETTE': 1,
#  'PUTEAUX': 8,
#  'PARC DES EXPOSITIONS': 29,
#  '  ZA Guyards': 1,
#  'BURES-SUR-YVETTE': 8,
#  'GALLIENI': 4,
#  'CAMPO-FORMIO': 6,
#  'MAIRIE DE MONTREUIL': 98,
#  'TERNES': 54,
#  'LAPLACE': 134,
#  'BOUCICAUT': 46,
#  'QUAI DE LA GARE': 39,
#  'FALGUIERE': 5,
#  'PLACE MONGE (JARDIN DES PLANTES)': 25,
#  'GAMBETTA': 58,
#  '   GARE NORD': 4,
#  'DOMONT': 17,
#  'MENNECY': 13,
#  'MAIRIE DE LIVRY - GARGAN': 1,
#  'ST CHRIST. RER': 13,
#  'EPINAY-VILLETANEUSE': 43,
#  'COURCELLE-SUR-YVETTE': 9,
#  'FOURNIER': 2,
#  'FREPILLON': 2,
#  'RUE DES BOULETS': 47,
#  'BROCHANT - CARDINET': 4,
#  'CHANTELOUP-LES-VIGNES': 3,
#  'JOURDAIN': 38,
#  'PARC MARTIN LUTHER KING': 4,
#  'Gare SNCF Villennes sur Seine': 1,
#  'LA FRETTE-MONTIGNY': 2,
#  'CRETEIL-PREFECTURE (HOTEL DE VILLE)': 13,
#  'NOISY-LE-SEC RER': 12,
#  'LA CHENEE': 1,
#  "GARE D'AUSTERLITZ                       ": 1,
#  'LAUMIERE': 12,
#  'CENTRE DE CHATILLON                     ': 1,
#  'Gare SNCF Mantes-la-Jolie': 6,
#  'GARGAN': 3,
#  'DAMMARTIN-JUILLY-SAINT-MARD': 5,
#  'MUSEE DE SEVRES': 2,
#  'THUN-LE-PARADIS': 2,
#  'MAISSE': 2,
#  'Gare Routière Emile Zola': 3,
#  'GROSLAY': 7,
#  'HOCHE': 14,
#  'BUSSY RER': 17,
#  'PETIT-VAUX': 3,
#  'PORTE DE MONTREUIL': 88,
#  'BLANC-MESNIL': 17,
#  'FONTENAY-AUX-ROSES': 27,
#  'RASPAIL': 5,
#  'CESSON': 32,
#  'GARE MASSY PALAISEAU': 22,
#  'COLLEGE AUGUSTIN BOSC': 1,
#  'PORTE DE CHOISY': 26,
#  'VILLEJUIF-PAUL VAILLANT-COUTURIER': 28,
#  'ERMONT-HALTE': 7,
#  'TREZEL': 4,
#  'MALAKOFF-PLATEAU DE VANVES': 23,
#  'JAVEL': 16,
#  'LA BARRE-ORMESSON': 21,
#  'VINCENNES RER - REPUBLIQUE': 12,
#  'LYCEE DE RUE': 2,
#  'MOULIN VERT                             ': 2,
#  'EGLISE DE PANTIN': 8,
#  'SULLY-MORLAND': 8,
#  'LIEGE': 17,
#  'BRANCION - VOUILLE': 1,
#  'DAUMESNIL': 69,
#  'CENTRE COMME': 2,
#  'PIERRE DEMOURS': 1,
#  'LA BUTTE VERTE': 3,
#  'QUATRE ROUTES': 1,
#  'CORMEILLES-EN-PARISIS': 4,
#  'BRETIGNY': 12,
#  'BERAULT': 42,
#  'SAINT-QUENTIN-EN-YVELINES': 6,
#  'GROS-NOYER-SAINT-PRIX': 13,
#  'DOMONT GARE SNCF': 1,
#  'Bazincourt': 2,
#  'GARGES-SARCELLES': 186,
#  'DAUMESNIL - DIDEROT': 2,
#  'RIS-ORANGIS': 17,
#  'MAIRIE DE VILLENEUVE LA GARENNE         ': 3,
#  'SAINT-MICHEL-SUR-ORGE': 6,
#  'MAIRIE DES LILAS': 38,
#  'LOUVRES': 16,
#  'CORVISART': 21,
#  'MONTAIGNE - FRANCOIS 1ER': 1,
#  'LES GOBELINS': 29,
#  'NOISY-CHAMPS RER                        ': 19,
#  'PHILIPPE AUGUSTE': 25,
#  'CONVENTION - LECOURBE': 1,
#  'SAN BENEDETTO': 6,
#  'RAYMOND POINCARE': 1,
#  'GARE ROUTIERE DE SARTROUVILLE': 25,
#  'KLEBER': 17,
#  'POINTE RINGA': 2,
#  'LOGNES RER': 5,
#  'GARE CORBEIL': 2,
#  'MAISON BLANCHE': 20,
#  'VIRY-CHATILLON': 5,
#  'GARE ROUTIERE DE HOUILLES': 19,
#  'PLACE DES FETES': 33,
#  'PONT DE NEUILLY-METRO': 2,
#  'ROBINSON': 51,
#  'RICHELIEU-DROUOT': 75,
#  'Hôtel de Ville de Sannois': 1,
#  'PONT DE BIR-HAKEIM': 8,
#  'Lovr-Louvres': 14,
#  'MAISONS-ALFORT-STADE': 21,
#  "Gare d'Emera": 5,
#  "VAL D'EUROPE RER": 27,
#  "TRINITE-D'ESTIENNE D'ORVES": 16,
#  'VILLENEUVE-TRIAGE': 8,
#  'GARE SAINT-LAZARE': 19,
#  'MAIRIE DE MONTREUIL-METRO': 15,
#  'PORTE DE SAINT-CLOUD - MICHEL ANGE': 2,
#  'PORTE DOREE': 26,
#  'EPINAY-SUR-ORGE': 5,
#  'VILLEPINTE': 8,
#  'EPONE-MEZIERES': 9,
#  'GARE DE CLICHY - LEVALLOIS': 19,
#  'LES ARDOINES': 3,
#  'ISSY-VAL DE SEINE': 7,
#  'BUZENVAL': 35,
#  'ERAGNY SNCF': 1,
#  'JEAN MERMOZ - HENRI BARBUSSE': 2,
#  'CORENTIN-CELTON': 12,
#  'PAIX - VERDUN': 3,
#  'Les Frênes': 1,
#  'PLACE DE BELGIQUE': 6,
#  "PLACE D'ITALIE - MAIRIE DU 13E": 1,
#  'CADET': 32,
#  'PORTE DE CLICHY': 40,
#  'PRESLES-COURCELLES': 2,
#  'ABLON': 2,
#  'CARNOT': 1,
#  ' Beoi-Mairie': 1,
#  "MAIRIE D'ALFORTVILLE": 9,
#  'SUCY-BONNEUIL RER                       ': 1,
#  "MAIRIE D'IVRY": 9,
#  'ROSNY - BOIS-PERRIER RER - ROSNY 2      ': 5,
#  'Aubo-Grossau': 5,
#  'VAUX-SUR-SEINE': 2,
#  'PONT DE LEVALLOIS-METRO': 1,
#  'SAINT-REMY-LES-CHEVREUSE': 7,
#  'SURVILLIERS-FOSSES': 23,
#  'LYON-LEDRU ROLLIN                       ': 4,
#  'BOUTIGNY-SUR-ESSONNE': 4,
#  'ROND POINT PASTEUR': 2,
#  'NANTERRE-VILLE RER': 5,
#  "Gare RER / Val d'Europe - Quai 2": 6,
#  'MICHEL BIZOT': 20,
#  'SAINT-MARCEL': 8,
#  'CHOISY-TOLBIAC                          ': 2,
#  'SIMPLON': 8,
#  'NANTERRE-UNIVERSITE RER                 ': 7,
#  'Marché': 1,
#  'VAVIN': 6,
#  'GARE DE LAGN': 1,
#  'EVRY': 5,
#  'WAGRAM': 25,
#  'LIEUSAINT  MOISSY GARE RER': 25,
#  'GLACIERE': 39,
#  'COURONNES': 34,
#  'EGLY': 1,
#  'TERROIRS DE FRANCE': 36,
#  '       LYCEE': 1,
#  'EUROPE': 16,
#  '                      Aubergenville gare': 1,
#  '                        Cergy Préfecture': 1,
#  'LES YVRIS-NOISY-LE-GRAND': 2,
#  'CHATEAU DE VILLEMOMBLE': 1,
#  'JEAN JAURES-HENRI BARBUSSE              ': 1,
#  'RUE DE LA STATION': 6,
#  'NOISY-LE-GRAND RER                      ': 3,
#  "PORTE D'ITALIE-METRO": 4,
#  'SAINT-MICHEL': 5,
#  'PUTEAUX La Défense - Terminal Jules Verne': 2,
#  'LE BRAS-DE-FER': 30,
#  'QUAI DE LA RAPEE': 7,
#  'SAINT EXUPERY': 1,
#  'MONTREUIL': 4,
#  'VIGNERONS': 1,
#  'AVENUE DE FRANCE                        ': 8,
#  'ALMA': 1,
#  'CHARENTON-ECOLES': 18,
#  'BILLANCOURT': 27,
#  'EDGAR QUINET': 19,
#  'MONTSOULT-MAFFLIERS': 8,
#  'BIBLIOTHEQUE RUE MANN': 3,
#  'CHAVILLE RIVE DROITE': 2,
#  "GARE  ROUTIERE  D'ENGHIEN": 7,
#  'SACCO ET VANZETTI': 1,
#  'FONTAINE-MICHALON': 23,
#  'CONFLANS-SAINTE-HONORINE': 20,
#  'PASTEUR - DOCTEUR ROUX': 5,
#  'SEVRAN - BEAUDOTTES RER': 1,
#  'GRANDS BOULEVARDS': 4,
#  'FORT DE CHAMPIGNY': 1,
#  'SAINT-PHILIPPE-DU-ROULE': 41,
#  'CORENTIN CARIOU': 32,
#  'PONT BINEAU': 1,
#  'LES NOUES': 14,
#  'SAINT-CLOUD': 8,
#  'BOURAY': 5,
#  'LEDRU-ROLLIN': 27,
#  'PORTE DE LA VILLETTE': 15,
#  'PORTE DE VERSAILLES': 22,
#  'PORTE DE COURCELLES': 2,
#  'Mairie': 6,
#  'VILLEJUIF - LOUIS ARAGON': 7,
#  'NANTERRE-PREFECTURE-RER                 ': 1,
#  '      COLMAR': 1,
#  'ALMA-MARCEAU': 20,
#  'CHAMPAGNE-SUR-OISE': 2,
#  'LA MUETTE': 13,
#  'DAMREMONT - MARCADET': 2,
#  '                     Chemin des meuniers': 1,
#  'PARMENTIER': 20,
#  'La Roseraie': 1,
#  'SAINT-MAUR': 25,
#  'RENNES': 6,
#  'LA HACQUINIERE': 8,
#  'CHENAY-GAGNY': 8,
#  'CITE DU VIEUX PONT': 2,
#  'LEON BLUM': 1,
#  'PLACE VOLTAIRE                          ': 2,
#  'Bobigny Pablo Picasso': 1,
#  'VIROFLAY RIVE GAUCHE': 1,
#  'GENERAL DE GAULLE': 3,
#  '       EDF 2': 1,
#  'CITE-PALAIS DE JUSTICE                  ': 3,
#  'Gare RER de MitryClaye': 2,
#  'Gare de Lozère': 2,
#  'NOISY-CHAMPS RER - DESCARTES': 2,
#  'PONSCARME': 1,
#  "ORANGIS-BOIS DE L'EPINE": 35,
#  'Evry-Courcouronnes Centre': 3,
#  'PONT DE VITRY': 2,
#  'NOTRE-DAME-DE-LORETTE': 16,
#  'EGLISE DE BONDY': 1,
#  'BOULOGNE-JEAN JAURES': 13,
#  '      PRAGUE': 1,
#  'SAINT-PLACIDE': 22,
#  'CHATEAU STE BARBE                       ': 1,
#  'Gare SNCF': 7,
#  'VILLENEUVE-LE-ROI': 4,
#  'CHOISY-LE-ROI RER                       ': 3,
#  'BELLOY-SAINT-MARTIN': 1,
#  'GALLIENI-METRO': 7,
#  'LENINE': 1,
#  'BONNIERES': 3,
#  'PEREIRE-LEVALLOIS': 34,
#  'MICHEL-ANGE-MOLITOR': 13,
#  'ECOLE MILITAIRE': 37,
#  'AVENUE SAINT-REMY': 1,
#  'LOURMEL': 32,
#  'CHARLEBOURG                             ': 8,
#  'LE FRESNE': 2,
#  'GLACIERE - ARAGO': 1,
#  'PLACE DE VERDUN                         ': 1,
#  "MERY-VAL D'OISE": 3,
#  'HOTEL DE VILLE DE FONTENAY-SOUS-BOIS': 1,
#  'CONVENTION - VAUGIRARD': 2,
#  "MAIRIE D'ISSY-METRO": 4,
#  "Conflans Fin d'Oise arrivée": 13,
#  'HOPITAL INTERCOMMUNAL': 3,
#  'MISSOUT': 1,
#  "MAIRIE D'IVRY-METRO": 4,
#  "VAL-D'ARGENTEUIL": 12,
#  'HOPITAL DU KREMLIN-BICETRE': 2,
#  "GARE ROUTIERE D'ARGENTEUIL": 7,
#  'CHARTRES': 1,
#  'ALLEE DE LA TOUR RENDEZ-VOUS': 1,
#  'LARDY': 1,
#  'VIARMES': 1,
#  'BOULEREAUX C': 1,
#  'Manoir': 1,
#  "PLACE DU 18 JUIN 1940 - RUE DE L'ARRIVEE": 1,
#  'PARIS G LYON': 1,
#  'CONSEIL GENERAL': 1,
#  'HAUSSMANN - MOGADOR': 1,
#  'PARC-DE-SCEAUX': 16,
#  'CHARLES HELLER                          ': 1,
#  'GONCOURT (HOPITAL SAINT-LOUIS)': 32,
#  'OLYMPIADES                              ': 10,
#  'CARREFOUR DE LA RESISTANCE              ': 1,
#  'CARREFOUR DE CHATEAUDUN': 4,
#  'PONT DE LA GRANDE JATTE': 4,
#  'Centre Commercial ulis 2': 2,
#  "PONT D'AUSTERLITZ - QUAI DE LA RAPEE": 3,
#  'DANIELLE CASANOVA                       ': 1,
#  'NOISY-LE-SEC RER                        ': 1,
#  'LA NORVILLE-SAINT-GERMAIN-LES-ARPAJON': 1,
#  'BUTTES-CHAUMONT': 4,
#  'REAUMUR-SEBASTOPOL': 14,
#  'SAINT-AMBROISE': 48,
#  'Gare RER - Quai de dépose': 12,
#  'VSG GareMairie': 6,
#  'PONT DE SEVRES': 19,
#  'MANTES-STATION': 12,
#  'NEUILLY-PLAISANCE RER.': 2,
#  'RAYMOND JACLARD': 6,
#  'CAMBRONNE - VAUGIRARD': 1,
#  'PORTE DE BAGNOLET': 22,
#  'LES BOURGUIGNONS': 1,
#  'Roissy RER': 4,
#  'GARE DE BONDY RER': 1,
#  'PETITS CHAMPS - DANIELLE CASANOVA': 2,
#  'Les Ecuyers': 1,
#  'JULES GUESDE                            ': 2,
#  'SURESNES-MONT VALERIEN': 3,
#  'MARLY-LE-ROI': 1,
#  'POMPIDOU                                ': 1,
#  'ESPLANADE C.D.G                         ': 7,
#  'LE KREMLIN-BICETRE-METRO': 6,
#  'MAIRIE DES LILAS - METRO': 4,
#  '      ZURICH': 2,
#  'VAUCELLES': 3,
#  'LES GRESILLONS': 2,
#  'FRATERNELLE': 3,
#  'LIMAY': 2,
#  'PALAIS ROYAL - COMEDIE FRANCAISE': 3,
#  'PARIS Gare d': 2,
#  'Orée de Sénart': 1,
#  'PIERRE DE GEYTER                        ': 1,
#  'GARGENVILLE': 1,
#  'Sucy RER': 37,
#  'CHARLES DE GAULLE - ETOILE - WAGRAM': 4,
#  'La Villeneuve': 1,
#  'PASSY - BOULAINVILLIERS': 1,
#  'KLEBER - PAUL VALERY': 3,
#  'BRUNOY GARE': 46,
#  'LOZERE': 10,
#  'VSG GARE ROUTIERE': 8,
#  'PISCINE': 1,
#  ' DEFENSE TJV': 9,
#  'Pôle Lafarge': 1,
#  'LIBERTE-METRO': 3,
#  'LYCEE HENRI SELLIER': 4,
#  "Gare d'Igny": 1,
#  'VILLENNES-SUR-SEINE': 2,
#  'SUZANNE LENGLEN': 10,
#  'HAUSSMANN - MIROMESNIL': 3,
#  'BOTZARIS': 6,
#  'LES COTEAUX': 2,
#  'Ml Juin': 1,
#  'DELAUNAY-BELLEVILLE                     ': 1,
#  ' POLY. LABO.': 1,
#  'VAL DE FONTENAY RER': 10,
#  'DENFERT-ROCHEREAU - DAGUERRE': 1,
#  'BELLINI': 2,
#  'LES MOULINEAUX                          ': 1,
#  'GARE -PANTIN': 1,
#  "CRETEIL-L'ECHAT (HOPITAL MONDOR)": 14,
#  'VERSAILLES CHATEAU': 3,
#  'MAURICE BARRES': 2,
#  'Pierre Curie': 2,
#  'MEDIATHEQUE DU SEGRAIS': 1,
#  'RAPP - LA BOURDONNAIS': 1,
#  'BRETIGNY GAR': 1,
#  'PAUL DOUMER': 2,
#  'OBERKAMPF': 23,
#  'JEAN MACE                               ': 3,
#  'LOUIS BLANC': 15,
#  'PIERRELAYE': 2,
#  'VICTOR BASCH                            ': 1,
#  'SCEAUX': 22,
#  'RUE DE SEINE': 4,
#  "Gare d'Orsay Ville": 1,
#  'Gare RER Poissy': 1,
#  'CHELLES-GOURNAY': 8,
#  'GARE DES MARCHANDISES': 5,
#  'Le Cep': 1,
#  'MARX DORMOY-CARNOT': 1,
#  'SAINT-DENIS GARE                        ': 6,
#  "Gare RER / Val d'Europe - Quai de dépose": 2,
#  'GABRIEL PERI-METRO': 5,
#  'EGLISE DE SAINT-MANDE': 2,
#  'ENGHIEN MERMOZ GARE': 6,
#  'LE CROULT': 1,
#  'NOGENT-LE-PERREUX RER': 10,
#  'ACHERES-GRAND-CORMIER': 1,
#  'PLACE DU 18 JUIN 1940': 2,
#  'Gosa-Résiden': 2,
#  'PORT AUX LIONS': 4,
#  'VOLTAIRE (LEON BLUM)': 59,
#  'QUATRE ROUTES                           ': 2,
#  'PLAISANCE - HOPITAL SAINT-JOSEPH': 3,
#  'COMBS LA VILLE GARE RER': 30,
#  'Gare Routière Bonnières': 1,
#  'Corneille': 1,
#  'SNCF': 8,
#  'PRES DES ROCHES': 1,
#  'RER Champigny': 9,
#  "Gare d'Epinay": 1,
#  'PAUL BERT': 3,
#  'Gare de Sartrouville': 19,
#  'LA PEROUSE                              ': 2,
#  'VILLIERS SUR MARNE-LE PLESSIS TREVISE-RER': 27,
#  'Prés St-Mart': 1,
#  'Trou Grillon 6': 1,
#  'Yerres GARE': 46,
#  'Grand Park': 1,
#  'EGLISE DE VILLIERS-SUR-MARNE': 1,
#  'LES QUATRE PAVES': 1,
#  'CESSON GARE RER': 12,
#  'DIJON - LACHAMBEAUDIE': 6,
#  'GARE DE LYON - DIDEROT': 41,
#  'Antony RER': 15,
#  'GEORGES MILLANDY                        ': 1,
#  'MLV GARE ROU': 1,
#  'LE MORILLON': 2,
#  'RUEIL-MALMAISON RER                     ': 1,
#  'Château': 1,
#  'COLOMBES': 15,
#  'LIBERATION': 4,
#  '    RER Sucy': 7,
#  'Palaiseau Ville': 6,
#  'Gare SNCF Vernouillet-Verneuil': 14,
#  'MAIRIE DE SAINT-OUEN - METRO': 1,
#  'Clos de Massy': 1,
#  'LE BONTEMPS': 2,
#  'ANCIENNE MAIRIE DE LE_BLANC-MESNIL': 6,
#  'JUSSIEU': 50,
#  'RIVOLI - PONT NEUF': 2,
#  'GARE DE LEST': 1,
#  'JASMIN': 14,
#  'COURS DE VINCENNES': 5,
#  'GARE SAINT LAZARE                       ': 3,
#  'MOISSY CENTRE': 1,
#  'THEATRE JOUY': 3,
#  'JACQUES BONSERGENT': 7,
#  'SAULE DE LA CHASSE': 1,
#  'MARX DORMOY': 13,
#  'VICTOR BASCH': 1,
#  'FONTAINEBLEAU-AVON': 2,
#  'CHATEAU DE VINCENNES-METRO              ': 5,
#  'Place Verte': 1,
#  'Gare de Massy Palaiseau B': 16,
#  'Gare de Saint Leu la Foret': 1,
#  'Aubrac': 1,
#  'SANNOIS': 8,
#  'LA BOISSIERE': 2,
#  'VILLABE': 2,
#  'BROSSOLETTE GARE DE BRETIGNY': 1,
#  'HENRI IV': 1,
#  'SOUS-PREFECTURE - JULES FERRY': 3,
#  'MAIRIE ST OUEN': 1,
#  'MAISONS-ALFORT - ALFORTVILLE RER.': 6,
#  'Gare du Vésinet Centre': 3,
#  'MONTGALLET': 10,
#  'CHARONNE-KELLER': 1,
#  'TRIEL-SUR-SEINE': 2,
#  'Gare de Montigny Beauchamp': 1,
#  'GRANGE AU BOIS': 2,
#  '   Torcy RER': 3,
#  'PONT DE TOLBIAC': 1,
#  'Asoi-Baillon': 2,
#  'MAIRIE DE VILLIERS-SUR-MARNE            ': 2,
#  "VAL D'EUROPE": 7,
#  'PONT DE NEUILLY': 5,
#  'Terminal Jules Verne': 5,
#  'ALSACE': 2,
#  'Temps des Cerises-Snecma': 4,
#  'Gare de Palaiseau Villebon': 1,
#  'RUE DES POMMIERS': 1,
#  'Montgeron GARE': 46,
#  'GAMBETTA - MAIRIE DU 20E': 6,
#  'LA CHALLE': 2,
#  'BASTILLE - RUE SAINT-ANTOINE': 2,
#  'LUZARCHES': 4,
#  'CROIX BLANCHE': 1,
#  'RUE DU POINT DU JOUR': 1,
#  'SOUVENIR FRANCAIS': 1,
#  "SAINT-OUEN-L'AUMONE-LIESSE": 3,
#  'ALESIA - RENE COTY': 1,
#  'EDOUARD VAILLANT': 2,
#  'GARCHES-MARNES-LA-COQUETTE': 1,
#  'BUNO-GIRONVILLE': 1,
#  'GARE MONTPARNASSE': 1,
#  'ERAGNY-NEUVILLE': 1,
#  'RER - RASPAIL': 1,
#  'Robert Capa': 1,
#  'LA PLAINE - STADE DE FRANCE RER': 5,
#  'LA FERTE-ALAIS': 2,
#  'NATIONALE': 39,
#  'PORTE DE VINCENNES                      ': 37,
#  'Gosa-Ecoleje': 1,
#  'GARE SAINT-LAZARE - BUDAPEST': 6,
#  'Gare de Saint Brice': 3,
#  'DRANCY RER': 28,
#  'CIMETIERE PARISIEN DE THIAIS': 1,
#  'ISSY': 2,
#  'ETAMPES': 3,
#  'ACHTARAK                                ': 2,
#  'Gare de Triel': 2,
#  "LE VAL-D'OR": 2,
#  'MAURICE BERTEAUX                        ': 2,
#  'PORT ROYAL-SAINT JACQUES                ': 1,
#  'Place du 14 Juillet': 2,
#  'Place de la Libération': 1,
#  'POSTE ZI BUSSY': 2,
#  'Fose-Hautegr': 2,
#  'CERGY LE HT RER': 25,
#  'ORLY OUEST - ARRIVEES DES VOLS': 1,
#  'GENERAL SCHRAMM': 12,
#  'PONT CARDINET': 7,
#  'ARISTIDE BRIAND-LE PLANT                ': 1,
#  'CENTRE NATIONAL DE LA DANSE': 2,
#  'Ozoir RER': 9,
#  "CHAUSSEE D'ANTIN": 1,
#  'PLACE DE LA LIBERATION': 3,
#  'OBSERVATOIRE - PORT ROYAL': 7,
#  'VALMONDOIS': 1,
#  'RAMBUTEAU': 9,
#  'OPERA - 4 SEPTEMBRE': 3,
#  'BRY-SUR-MARNE RER': 2,
#  'HAVRE - CAUMARTIN': 4,
#  'FILLES DU CALVAIRE': 12,
#  ' Vipa-Marché': 10,
#  'Henri Janin': 2,
#  'COLLEGE LE LUZARD': 1,
#  'Aubo-Aulnays': 9,
#  'COLETTE BESSON                          ': 2,
#  'JOINVILLE-LE-PONT-RER': 6,
#  'ROUGET DE LISLE': 3,
#  'PONT SAINT-MICHEL - QUAI DES ORFEVRES': 1,
#  'PRESIDENT ALLENDE': 2,
#  'LA CHAMPAGNE': 1,
#  "RUE DE L'AIGLE": 2,
#  "Z. A. de l'Ormois": 1,
#  'Gare Nord départ': 30,
#  'AVENUE HENRI MARTIN': 4,
#  'COMBS HOTEL DE VILLE': 1,
#  'MAGENTA - SAINT-MARTIN': 1,
#  'AVRON': 15,
#  'UNIVERSITE': 4,
#  'Petite Montagne': 1,
#  'HOPITAL BEAUJON': 3,
#  'Rue de Choisy': 1,
#  'CERGY PREFECTURE': 3,
#  'Rue des Carrières': 1,
#  "Pontault RER (rue de l'Est)": 3,
#  'SAINT-OUEN': 10,
#  'GENERAL LECLERC': 1,
#  'PLACE DE LA PAIX': 1,
#  'MAROLLES-EN-HUREPOIX': 2,
#  'GABRIEL PERI - DE GAULLE': 1,
#  'Pierrerie': 1,
#  'RUE DU TIR': 3,
#  'PIERREFITTE - STAINS RER': 7,
#  'MONTEREAU': 1,
#  'CHATEAU                                 ': 2,
#  'LES BLEUETS': 2,
#  '11 NOVEMBRE 1918': 1,
#  'LES AMBASSADEURS': 1,
#  '        PONT': 1,
#  'SAINT-MAUR-CRETEIL-RER': 4,
#  ...}

# %%
len(D_counts)
# Out:
# 2078

# %%
counts_counts = get_counts(get_counts(finall_result['client_id']).values())

# %%
y_counts = sorted(counts_counts.values(), reverse = True)
y_counts[0] = y_counts[0] * 2
y_counts[1] = y_counts[1] * 3
y_counts[2] = y_counts[2] * 4
y_counts[3] = y_counts[3] * 5
y_counts[4] = y_counts[4] * 6
y_counts[5] = y_counts[5] * 7
y_counts
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-0f41c66e675d> in <module>()
#       3 y_counts[1] = y_counts[1] * 3
#       4 y_counts[2] = y_counts[2] * 4
# ----> 5 y_counts[3] = y_counts[3] * 5
#       6 y_counts[4] = y_counts[4] * 6
#       7 y_counts[5] = y_counts[5] * 7
#
# IndexError: list index out of range

# %%
plt.bar(np.arange(len(counts_counts)) ,y_counts)
plt.xticks(np.arange(len(counts_counts)), [2,3,4,5,6,7,1])
plt.xlabel('transfers')
plt.ylabel('counts')
plt.show()

# Validation -> Transfer

# %%
id_counts = get_counts(finall_result['client_id'])
counts = []
for a in id_counts.keys():
    temp = finall_result[finall_result['client_id'] == a ]
    counts.extend((get_counts(temp['trip_id'])).values())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-108-536b680d301e> in <module>()
#       2 counts = []
#       3 for a in id_counts.keys():
# ----> 4     temp = finall_result[finall_result['client_id'] == a ]
#       5     counts.extend((get_counts(temp['trip_id'])).values())
#
# E:\python\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# E:\python\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    1997             # be reindexed to match DataFrame rows
#    1998             key = check_bool_indexer(self.index, key)
# -> 1999             indexer = key.nonzero()[0]
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
#
# KeyboardInterrupt:
